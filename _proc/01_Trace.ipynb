# %% [markdown]
# ## Explore a long source code

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
# from IPython.core.display import display, HTML # a depreciated import
from IPython.display import display, HTML

# %%
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import snoop
from fastdebug.utils import whatinside
import inspect

# %%
inspect._signature_from_callable(whatinside, sigcls=inspect.Signature)
# Out:
# <Signature (mo, dun: bool = False, func: bool = False, clas: bool = False, bltin: bool = False, lib: bool = False, cal: bool = False)>

# %%
# lst = "inspect._signature_from_callable(whatinside, sigcls=inspect.Signature)".split('(')
# snp = "snoop.snoop(depth=1)(" + lst[0] + ")(" + lst[1]
# snp

# %%
# eval(snp)

# %%
# snoop.snoop(depth=1)(inspect._signature_from_callable)(whatinside, sigcls=inspect.Signature)

# %%
from fastdebug.core import *

# %%
fdb = Fastdb(inspect._signature_from_callable)

# %%
fdb.takExample("inspect._signature_from_callable(whatinside, sigcls=inspect.Signature)", inspect=inspect, whatinside=whatinside)

# %%
fdb.snoop()
# Out:
# 22:55:41.87 >>> Call to _signature_from_callable in File "/Users/Natsume/mambaforge/lib/python3.9/inspect.py", line 2246
# 22:55:41.87 ...... obj = <function whatinside at 0x1222b2550>
# 22:55:41.87 ...... follow_wrapper_chains = True
# 22:55:41.87 ...... skip_bound_arg = True
# 22:55:41.87 ...... sigcls = <class 'inspect.Signature'>
# 22:55:41.87 2246 | def _signature_from_callable(obj, *,
# 22:55:41.87 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:41.87 2256 |                                 follow_wrapper_chains=follow_wrapper_chains,
# 22:55:41.87 2257 |                                 skip_bound_arg=skip_bound_arg,
# 22:55:41.87 2258 |                                 sigcls=sigcls)
# 22:55:41.87 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:41.87 .......... _get_signature_of = functools.partial(<function _signature_from_call...und_arg=True, sigcls=<class 'inspect.Signature'>)
# 22:55:41.87 2260 |     if not callable(obj):
# 22:55:41.87 2263 |     if isinstance(obj, types.MethodType):
# 22:55:41.87 2274 |     if follow_wrapper_chains:
# 22:55:41.88 2275 |         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))
# 22:55:41.88 2276 |         if isinstance(obj, types.MethodType):
# 22:55:41.88 2282 |     try:
# 22:55:41.88 2283 |         sig = obj.__signature__
# 22:55:42.21 !!! AttributeError: 'function' object has no attribute '__signature__'
# 22:55:42.21 !!! When getting attribute: obj.__signature__
# 22:55:42.21 2284 |     except AttributeError:
# 22:55:42.21 2285 |         pass
# 22:55:42.21 2294 |     try:
# 22:55:42.21 2295 |         partialmethod = obj._partialmethod
# 22:55:42.23 !!! AttributeError: 'function' object has no attribute '_partialmethod'
# 22:55:42.23 !!! When getting attribute: obj._partialmethod
# 22:55:42.23 2296 |     except AttributeError:
# 22:55:42.23 2297 |         pass
# 22:55:42.23 2322 |     if isfunction(obj) or _signature_is_functionlike(obj):
# 22:55:42.23 2325 |         return _signature_from_function(sigcls, obj,
# 22:55:42.23 2326 |                                         skip_bound_arg=skip_bound_arg)
# 22:55:42.23 2325 |         return _signature_from_function(sigcls, obj,
# 22:55:42.23 <<< Return value from _signature_from_callable: <Signature (mo, dun: bool = False, func: bool = ...l = False, lib: bool = False, cal: bool = False)>

# %%
fdb.dbprint(76, "whatinside's sig is finally processed by _signature_from_function", "obj", "isfunction(obj)")
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ===============================================================     on line 76     ===============================================================
# ==========================     with example inspect._signature_from_callable(whatinside, sigcls=inspect.Signature)     ===========================
#
#                 return sig.replace(parameters=new_params)                                                                                               (74)
#                                                                                                                                                         (75)
#     if isfunction(obj) or _signature_is_functionlike(obj):==============================================================================================(76)
#                                                                                             whatinside's sig is finally processed by _signature_from_function
#         # If it's a pure Python function, or an object that is duck type                                                                                (77)
#         # of a Python function (Cython functions, for instance), then:                                                                                  (78)
#
# ==================================================================================================================Start of my srcline exploration:
#
#
#                                                                                                             obj => obj : <function whatinside at 0x1222b2550>
#
#
#                                                                                                                     isfunction(obj) => isfunction(obj) : True
# ====================================================================================================================End of my srcline exploration:
#
# <Signature (mo, dun: bool = False, func: bool = False, clas: bool = False, bltin: bool = False, lib: bool = False, cal: bool = False)>
#
# Review srcode with all comments added so far======================================================================================================
#                 # First argument of the wrapped callable is `*args`, as in================(66)
#                 # `partialmethod(lambda *args)`.==========================================(67)
#                 return sig================================================================(68)
#             else:=========================================================================(69)
#                 sig_params = tuple(sig.parameters.values())===============================(70)
#                 assert (not sig_params or=================================================(71)
#                         first_wrapped_param is not sig_params[0])=========================(72)
#                 new_params = (first_wrapped_param,) + sig_params==========================(73)
#                 return sig.replace(parameters=new_params)=================================(74)
#                                                                                                                                                         (75)
#     if isfunction(obj) or _signature_is_functionlike(obj):================================(76) # step 0: whatinside's sig is finally processed by _signature_from_function
#         # If it's a pure Python function, or an object that is duck type==================(77)
#         # of a Python function (Cython functions, for instance), then:====================(78)
#         return _signature_from_function(sigcls, obj,======================================(79)
#                                         skip_bound_arg=skip_bound_arg)====================(80)
#                                                                                                                                                         (81)
#     if _signature_is_builtin(obj):========================================================(82)
#         return _signature_from_builtin(sigcls, obj,=======================================(83)
#                                        skip_bound_arg=skip_bound_arg)=====================(84)
#                                                                                                                                                         (85)
#     if isinstance(obj, functools.partial):================================================(86)
#         wrapped_sig = _get_signature_of(obj.func)=========================================(87)
#         return _signature_get_partial(wrapped_sig, obj)===================================(88)
#                                                                                                                                                         (89)
#     sig = None============================================================================(90)
#     if isinstance(obj, type):=============================================================(91)
#         # obj is a class or a metaclass===================================================(92)
#                                                                                                                                                         (93)
#         # First, let's see if it has an overloaded __call__ defined=======================(94)
#         # in its metaclass================================================================(95)
#         call = _signature_get_user_defined_method(type(obj), '__call__')==================(96)
#         if call is not None:==============================================================(97)
#             sig = _get_signature_of(call)=================================================(98)
#                                                                                                                                      part No.3 out of 6 parts
# <function inspect._signature_from_callable(obj, *, follow_wrapper_chains=True, skip_bound_arg=True, sigcls)>

# %%
class Foo_init:
    def __init__(self, a, b, c): pass

inspect._signature_from_callable(Foo_init, sigcls=inspect.Signature)
# Out:
# <Signature (a, b, c)>

# %%
example = """
class Foo_init:
    def __init__(self, a, b, c): pass

inspect._signature_from_callable(Foo_init, sigcls=inspect.Signature)
"""

# %%
# snoop.snoop(depth=1)(inspect._signature_from_callable)(Foo_init, sigcls=inspect.Signature)

# %%
# fdb.takExample("inspect._signature_from_callable(Foo_init, sigcls=inspect.Signature)", inspect=inspect, Foo_init=Foo_init)

# %%
fdb.takExample(example, inspect=inspect, Foo_init=Foo_init)

# %%
fdb.orisrc.__name__
# Out:
# '_signature_from_callable'

# %%
fdb.snoop()
# Out:
# 22:55:42.27 >>> Call to _signature_from_callable in File "/Users/Natsume/mambaforge/lib/python3.9/inspect.py", line 2246
# 22:55:42.27 ...... obj = <class '__main__.Foo_init'>
# 22:55:42.27 ...... follow_wrapper_chains = True
# 22:55:42.27 ...... skip_bound_arg = True
# 22:55:42.27 ...... sigcls = <class 'inspect.Signature'>
# 22:55:42.27 2246 | def _signature_from_callable(obj, *,
# 22:55:42.27 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:42.27 2256 |                                 follow_wrapper_chains=follow_wrapper_chains,
# 22:55:42.27 2257 |                                 skip_bound_arg=skip_bound_arg,
# 22:55:42.27 2258 |                                 sigcls=sigcls)
# 22:55:42.27 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:42.27 .......... _get_signature_of = functools.partial(<function _signature_from_call...und_arg=True, sigcls=<class 'inspect.Signature'>)
# 22:55:42.27 2260 |     if not callable(obj):
# 22:55:42.27 2263 |     if isinstance(obj, types.MethodType):
# 22:55:42.27 2274 |     if follow_wrapper_chains:
# 22:55:42.27 2275 |         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))
# 22:55:42.27 2276 |         if isinstance(obj, types.MethodType):
# 22:55:42.27 2282 |     try:
# 22:55:42.27 2283 |         sig = obj.__signature__
# 22:55:42.27 !!! AttributeError: type object 'Foo_init' has no attribute '__signature__'
# 22:55:42.27 !!! When getting attribute: obj.__signature__
# 22:55:42.27 2284 |     except AttributeError:
# 22:55:42.27 2285 |         pass
# 22:55:42.27 2294 |     try:
# 22:55:42.27 2295 |         partialmethod = obj._partialmethod
# 22:55:42.27 !!! AttributeError: type object 'Foo_init' has no attribute '_partialmethod'
# 22:55:42.27 !!! When getting attribute: obj._partialmethod
# 22:55:42.27 2296 |     except AttributeError:
# 22:55:42.27 2297 |         pass
# 22:55:42.27 2322 |     if isfunction(obj) or _signature_is_functionlike(obj):
# 22:55:42.27 2328 |     if _signature_is_builtin(obj):
# 22:55:42.27 2332 |     if isinstance(obj, functools.partial):
# 22:55:42.27 2336 |     sig = None
# 22:55:42.27 2337 |     if isinstance(obj, type):
# 22:55:42.27 2342 |         call = _signature_get_user_defined_method(type(obj), '__call__')
# 22:55:42.27 .............. call = None
# 22:55:42.27 2343 |         if call is not None:
# 22:55:42.27 2346 |             factory_method = None
# 22:55:42.27 2347 |             new = _signature_get_user_defined_method(obj, '__new__')
# 22:55:42.27 .................. new = None
# 22:55:42.27 2348 |             init = _signature_get_user_defined_method(obj, '__init__')
# 22:55:42.27 .................. init = <function Foo_init.__init__ at 0x12746d5e0>
# 22:55:42.27 2350 |             if '__new__' in obj.__dict__:
# 22:55:42.27 2353 |             elif '__init__' in obj.__dict__:
# 22:55:42.27 2354 |                 factory_method = init
# 22:55:42.27 ...................... factory_method = <function Foo_init.__init__ at 0x12746d5e0>
# 22:55:42.27 2361 |             if factory_method is not None:
# 22:55:42.28 2362 |                 sig = _get_signature_of(factory_method)
#     22:55:42.28 >>> Call to _signature_from_callable in File "/Users/Natsume/mambaforge/lib/python3.9/inspect.py", line 2246
#     22:55:42.28 ...... obj = <function Foo_init.__init__ at 0x12746d5e0>
#     22:55:42.28 ...... follow_wrapper_chains = True
#     22:55:42.28 ...... skip_bound_arg = True
#     22:55:42.28 ...... sigcls = <class 'inspect.Signature'>
#     22:55:42.28 2246 | def _signature_from_callable(obj, *,
#     22:55:42.28 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
#     22:55:42.28 2256 |                                 follow_wrapper_chains=follow_wrapper_chains,
#     22:55:42.28 2257 |                                 skip_bound_arg=skip_bound_arg,
#     22:55:42.28 2258 |                                 sigcls=sigcls)
#     22:55:42.28 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
#     22:55:42.28 .......... _get_signature_of = functools.partial(<function _signature_from_call...und_arg=True, sigcls=<class 'inspect.Signature'>)
#     22:55:42.28 2260 |     if not callable(obj):
#     22:55:42.28 2263 |     if isinstance(obj, types.MethodType):
#     22:55:42.28 2274 |     if follow_wrapper_chains:
#     22:55:42.28 2275 |         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))
#     22:55:42.28 2276 |         if isinstance(obj, types.MethodType):
#     22:55:42.28 2282 |     try:
#     22:55:42.28 2283 |         sig = obj.__signature__
#     22:55:42.28 !!! AttributeError: 'function' object has no attribute '__signature__'
#     22:55:42.28 !!! When getting attribute: obj.__signature__
#     22:55:42.28 2284 |     except AttributeError:
#     22:55:42.28 2285 |         pass
#     22:55:42.28 2294 |     try:
#     22:55:42.28 2295 |         partialmethod = obj._partialmethod
#     22:55:42.28 !!! AttributeError: 'function' object has no attribute '_partialmethod'
#     22:55:42.28 !!! When getting attribute: obj._partialmethod
#     22:55:42.28 2296 |     except AttributeError:
#     22:55:42.28 2297 |         pass
#     22:55:42.28 2322 |     if isfunction(obj) or _signature_is_functionlike(obj):
#     22:55:42.28 2325 |         return _signature_from_function(sigcls, obj,
#     22:55:42.28 2326 |                                         skip_bound_arg=skip_bound_arg)
#     22:55:42.28 2325 |         return _signature_from_function(sigcls, obj,
#     22:55:42.28 <<< Return value from _signature_from_callable: <Signature (self, a, b, c)>
# 22:55:42.28 2362 |                 sig = _get_signature_of(factory_method)
# 22:55:42.28 ...................... sig = <Signature (self, a, b, c)>
# 22:55:42.28 2364 |         if sig is None:
# 22:55:42.28 2413 |     if sig is not None:
# 22:55:42.28 2416 |         if skip_bound_arg:
# 22:55:42.28 2417 |             return _signature_bound_method(sig)
# 22:55:42.28 <<< Return value from _signature_from_callable: <Signature (a, b, c)>

# %%
fdb.dbprint(91, "Foo is taken care of in this if block", "isinstance(obj, type)")
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ===============================================================     on line 91     ===============================================================
#      with example
# class Foo_init:
#     def __init__(self, a, b, c): pass
#
# inspect._signature_from_callable(Foo_init, sigcls=inspect.Signature)
#
#
#                                                                                                                                                         (89)
#     sig = None                                                                                                                                          (90)
#     if isinstance(obj, type):===========================================================================================================================(91)
#                                                                                                                         Foo is taken care of in this if block
#         # obj is a class or a metaclass                                                                                                                 (92)
#                                                                                                                                                         (93)
#
# ==================================================================================================================Start of my srcline exploration:
#
#
#                                                                                                         isinstance(obj, type) => isinstance(obj, type) : True
# ====================================================================================================================End of my srcline exploration:
#
# <Signature (a, b, c)>
#
# Review srcode with all comments added so far======================================================================================================
#                 # First argument of the wrapped callable is `*args`, as in================(66)
#                 # `partialmethod(lambda *args)`.==========================================(67)
#                 return sig================================================================(68)
#             else:=========================================================================(69)
#                 sig_params = tuple(sig.parameters.values())===============================(70)
#                 assert (not sig_params or=================================================(71)
#                         first_wrapped_param is not sig_params[0])=========================(72)
#                 new_params = (first_wrapped_param,) + sig_params==========================(73)
#                 return sig.replace(parameters=new_params)=================================(74)
#                                                                                                                                                         (75)
#     if isfunction(obj) or _signature_is_functionlike(obj):================================(76) # step 0: whatinside's sig is finally processed by _signature_from_function
#         # If it's a pure Python function, or an object that is duck type==================(77)
#         # of a Python function (Cython functions, for instance), then:====================(78)
#         return _signature_from_function(sigcls, obj,======================================(79)
#                                         skip_bound_arg=skip_bound_arg)====================(80)
#                                                                                                                                                         (81)
#     if _signature_is_builtin(obj):========================================================(82)
#         return _signature_from_builtin(sigcls, obj,=======================================(83)
#                                        skip_bound_arg=skip_bound_arg)=====================(84)
#                                                                                                                                                         (85)
#     if isinstance(obj, functools.partial):================================================(86)
#         wrapped_sig = _get_signature_of(obj.func)=========================================(87)
#         return _signature_get_partial(wrapped_sig, obj)===================================(88)
#                                                                                                                                                         (89)
#     sig = None============================================================================(90)
#     if isinstance(obj, type):=============================================================(91) # step 1: Foo is taken care of in this if block
#         # obj is a class or a metaclass===================================================(92)
#                                                                                                                                                         (93)
#         # First, let's see if it has an overloaded __call__ defined=======================(94)
#         # in its metaclass================================================================(95)
#         call = _signature_get_user_defined_method(type(obj), '__call__')==================(96)
#         if call is not None:==============================================================(97)
#             sig = _get_signature_of(call)=================================================(98)
#                                                                                                                                      part No.3 out of 6 parts
# <function inspect._signature_from_callable(obj, *, follow_wrapper_chains=True, skip_bound_arg=True, sigcls)>

# %%
fdb.dbprint(103, "Foo has no methods on call nor new, but has init", "call", "new", "init")
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ==============================================================     on line 103     ===============================================================
#      with example
# class Foo_init:
#     def __init__(self, a, b, c): pass
#
# inspect._signature_from_callable(Foo_init, sigcls=inspect.Signature)
#
#
#             new = _signature_get_user_defined_method(obj, '__new__')                                                                                    (101)
#             init = _signature_get_user_defined_method(obj, '__init__')                                                                                  (102)
#             # Now we check if the 'obj' class has an own '__new__' method===============================================================================(103)
#                                                                                                              Foo has no methods on call nor new, but has init
#             if '__new__' in obj.__dict__:                                                                                                               (104)
#                 factory_method = new                                                                                                                    (105)
#
# ==================================================================================================================Start of my srcline exploration:
#
#
#                                                                                                                                           call => call : None
#
#
#                                                                                                                                             new => new : None
#
#
#                                                                                                    init => init : <function Foo_init.__init__ at 0x12746d5e0>
# ====================================================================================================================End of my srcline exploration:
#
# <Signature (a, b, c)>
#
# Review srcode with all comments added so far======================================================================================================
#         else:=============================================================================(99)
#             factory_method = None=========================================================(100)
#             new = _signature_get_user_defined_method(obj, '__new__')======================(101)
#             init = _signature_get_user_defined_method(obj, '__init__')====================(102)
#             # Now we check if the 'obj' class has an own '__new__' method=================(103) # step 2: Foo has no methods on call nor new, but has init
#             if '__new__' in obj.__dict__:=================================================(104)
#                 factory_method = new======================================================(105)
#             # or an own '__init__' method=================================================(106)
#             elif '__init__' in obj.__dict__:==============================================(107)
#                 factory_method = init=====================================================(108)
#             # If not, we take inherited '__new__' or '__init__', if present===============(109)
#             elif new is not None:=========================================================(110)
#                 factory_method = new======================================================(111)
#             elif init is not None:========================================================(112)
#                 factory_method = init=====================================================(113)
#                                                                                                                                                         (114)
#             if factory_method is not None:================================================(115)
#                 sig = _get_signature_of(factory_method)===================================(116)
#                                                                                                                                                         (117)
#         if sig is None:===================================================================(118)
#             # At this point we know, that `obj` is a class, with no user-=================(119)
#             # defined '__init__', '__new__', or class-level '__call__'====================(120)
#                                                                                                                                                         (121)
#             for base in obj.__mro__[:-1]:=================================================(122)
#                 # Since '__text_signature__' is implemented as a==========================(123)
#                 # descriptor that extracts text signature from the========================(124)
#                 # class docstring, if 'obj' is derived from a builtin=====================(125)
#                 # class, its own '__text_signature__' may be 'None'.======================(126)
#                 # Therefore, we go through the MRO (except the last=======================(127)
#                 # class in there, which is 'object') to find the first====================(128)
#                 # class with non-empty text signature.====================================(129)
#                 try:======================================================================(130)
#                     text_sig = base.__text_signature__====================================(131)
#                                                                                                                                      part No.4 out of 6 parts
# <function inspect._signature_from_callable(obj, *, follow_wrapper_chains=True, skip_bound_arg=True, sigcls)>

# %%
fdb.dbprint(116, "init func is taken by _get_signature_of", "init == factory_method")
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ==============================================================     on line 116     ===============================================================
#      with example
# class Foo_init:
#     def __init__(self, a, b, c): pass
#
# inspect._signature_from_callable(Foo_init, sigcls=inspect.Signature)
#
#
#                                                                                                                                                         (114)
#             if factory_method is not None:                                                                                                              (115)
#                 sig = _get_signature_of(factory_method)=================================================================================================(116)
#                                                                                                                       init func is taken by _get_signature_of
#                                                                                                                                                         (117)
#         if sig is None:                                                                                                                                 (118)
#
# ==================================================================================================================Start of my srcline exploration:
#
#
#                                                                                                        init == factory_method => init == factory_method: True
# ====================================================================================================================End of my srcline exploration:
#
# <Signature (a, b, c)>
#
# Review srcode with all comments added so far======================================================================================================
#         else:=============================================================================(99)
#             factory_method = None=========================================================(100)
#             new = _signature_get_user_defined_method(obj, '__new__')======================(101)
#             init = _signature_get_user_defined_method(obj, '__init__')====================(102)
#             # Now we check if the 'obj' class has an own '__new__' method=================(103) # step 2: Foo has no methods on call nor new, but has init
#             if '__new__' in obj.__dict__:=================================================(104)
#                 factory_method = new======================================================(105)
#             # or an own '__init__' method=================================================(106)
#             elif '__init__' in obj.__dict__:==============================================(107)
#                 factory_method = init=====================================================(108)
#             # If not, we take inherited '__new__' or '__init__', if present===============(109)
#             elif new is not None:=========================================================(110)
#                 factory_method = new======================================================(111)
#             elif init is not None:========================================================(112)
#                 factory_method = init=====================================================(113)
#                                                                                                                                                         (114)
#             if factory_method is not None:================================================(115)
#                 sig = _get_signature_of(factory_method)===================================(116) # step 3: init func is taken by _get_signature_of
#                                                                                                                                                         (117)
#         if sig is None:===================================================================(118)
#             # At this point we know, that `obj` is a class, with no user-=================(119)
#             # defined '__init__', '__new__', or class-level '__call__'====================(120)
#                                                                                                                                                         (121)
#             for base in obj.__mro__[:-1]:=================================================(122)
#                 # Since '__text_signature__' is implemented as a==========================(123)
#                 # descriptor that extracts text signature from the========================(124)
#                 # class docstring, if 'obj' is derived from a builtin=====================(125)
#                 # class, its own '__text_signature__' may be 'None'.======================(126)
#                 # Therefore, we go through the MRO (except the last=======================(127)
#                 # class in there, which is 'object') to find the first====================(128)
#                 # class with non-empty text signature.====================================(129)
#                 try:======================================================================(130)
#                     text_sig = base.__text_signature__====================================(131)
#                                                                                                                                      part No.4 out of 6 parts
# <function inspect._signature_from_callable(obj, *, follow_wrapper_chains=True, skip_bound_arg=True, sigcls)>

# %%
fdb.dbprint(77, "init func will be processed by _signature_from_function in the block above. see explorations below:", "obj.__init__", \
            "_signature_from_function(sigcls, obj.__init__, skip_bound_arg=skip_bound_arg)")
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ===============================================================     on line 77     ===============================================================
#      with example
# class Foo_init:
#     def __init__(self, a, b, c): pass
#
# inspect._signature_from_callable(Foo_init, sigcls=inspect.Signature)
#
#
#                                                                                                                                                         (75)
#     if isfunction(obj) or _signature_is_functionlike(obj):                                                                                              (76)
#         # If it's a pure Python function, or an object that is duck type================================================================================(77)
#                                                           init func will be processed by _signature_from_function in the block above. see explorations below:
#         # of a Python function (Cython functions, for instance), then:                                                                                  (78)
#         return _signature_from_function(sigcls, obj,                                                                                                    (79)
# <Signature (a, b, c)>
#
# Review srcode with all comments added so far======================================================================================================
#                 # First argument of the wrapped callable is `*args`, as in================(66)
#                 # `partialmethod(lambda *args)`.==========================================(67)
#                 return sig================================================================(68)
#             else:=========================================================================(69)
#                 sig_params = tuple(sig.parameters.values())===============================(70)
#                 assert (not sig_params or=================================================(71)
#                         first_wrapped_param is not sig_params[0])=========================(72)
#                 new_params = (first_wrapped_param,) + sig_params==========================(73)
#                 return sig.replace(parameters=new_params)=================================(74)
#                                                                                                                                                         (75)
#     if isfunction(obj) or _signature_is_functionlike(obj):================================(76) # step 0: whatinside's sig is finally processed by _signature_from_function
#         # If it's a pure Python function, or an object that is duck type==================(77) # step 4: init func will be processed by _signature_from_function in the block above. see explorations below:
#         # of a Python function (Cython functions, for instance), then:====================(78)
#         return _signature_from_function(sigcls, obj,======================================(79)
#                                         skip_bound_arg=skip_bound_arg)====================(80)
#                                                                                                                                                         (81)
#     if _signature_is_builtin(obj):========================================================(82)
#         return _signature_from_builtin(sigcls, obj,=======================================(83)
#                                        skip_bound_arg=skip_bound_arg)=====================(84)
#                                                                                                                                                         (85)
#     if isinstance(obj, functools.partial):================================================(86)
#         wrapped_sig = _get_signature_of(obj.func)=========================================(87)
#         return _signature_get_partial(wrapped_sig, obj)===================================(88)
#                                                                                                                                                         (89)
#     sig = None============================================================================(90)
#     if isinstance(obj, type):=============================================================(91) # step 1: Foo is taken care of in this if block
#         # obj is a class or a metaclass===================================================(92)
#                                                                                                                                                         (93)
#         # First, let's see if it has an overloaded __call__ defined=======================(94)
#         # in its metaclass================================================================(95)
#         call = _signature_get_user_defined_method(type(obj), '__call__')==================(96)
#         if call is not None:==============================================================(97)
#             sig = _get_signature_of(call)=================================================(98)
#                                                                                                                                      part No.3 out of 6 parts
# <function inspect._signature_from_callable(obj, *, follow_wrapper_chains=True, skip_bound_arg=True, sigcls)>

# %%
class Base: # pass
    def __new__(self, **args): pass  # defines a __new__ 

class Foo_new(Base):
    def __init__(self, d, e, f): pass
    
inspect._signature_from_callable(Foo_new, sigcls=inspect.Signature)
# Out:
# <Signature (d, e, f)>

# %%
# snoop.snoop(depth=1)(inspect._signature_from_callable)(Foo_new, sigcls=inspect.Signature)

# %%
example = """
class Base: # pass
    def __new__(self, **args): pass  # defines a __new__ 

class Foo_new(Base):
    def __init__(self, d, e, f): pass
    
inspect._signature_from_callable(Foo_new, sigcls=inspect.Signature)
"""

# %%
fdb.takExample(example, inspect=inspect, Foo_new=Foo_new)

# %%
fdb.snoop()
# Out:
# 22:55:42.35 >>> Call to _signature_from_callable in File "/Users/Natsume/mambaforge/lib/python3.9/inspect.py", line 2246
# 22:55:42.35 ...... obj = <class '__main__.Foo_new'>
# 22:55:42.35 ...... follow_wrapper_chains = True
# 22:55:42.35 ...... skip_bound_arg = True
# 22:55:42.35 ...... sigcls = <class 'inspect.Signature'>
# 22:55:42.35 2246 | def _signature_from_callable(obj, *,
# 22:55:42.35 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:42.35 2256 |                                 follow_wrapper_chains=follow_wrapper_chains,
# 22:55:42.35 2257 |                                 skip_bound_arg=skip_bound_arg,
# 22:55:42.35 2258 |                                 sigcls=sigcls)
# 22:55:42.35 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:42.35 .......... _get_signature_of = functools.partial(<function _signature_from_call...und_arg=True, sigcls=<class 'inspect.Signature'>)
# 22:55:42.35 2260 |     if not callable(obj):
# 22:55:42.35 2263 |     if isinstance(obj, types.MethodType):
# 22:55:42.35 2274 |     if follow_wrapper_chains:
# 22:55:42.35 2275 |         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))
# 22:55:42.35 2276 |         if isinstance(obj, types.MethodType):
# 22:55:42.35 2282 |     try:
# 22:55:42.35 2283 |         sig = obj.__signature__
# 22:55:42.35 !!! AttributeError: type object 'Foo_new' has no attribute '__signature__'
# 22:55:42.35 !!! When getting attribute: obj.__signature__
# 22:55:42.35 2284 |     except AttributeError:
# 22:55:42.35 2285 |         pass
# 22:55:42.35 2294 |     try:
# 22:55:42.35 2295 |         partialmethod = obj._partialmethod
# 22:55:42.35 !!! AttributeError: type object 'Foo_new' has no attribute '_partialmethod'
# 22:55:42.35 !!! When getting attribute: obj._partialmethod
# 22:55:42.35 2296 |     except AttributeError:
# 22:55:42.35 2297 |         pass
# 22:55:42.35 2322 |     if isfunction(obj) or _signature_is_functionlike(obj):
# 22:55:42.35 2328 |     if _signature_is_builtin(obj):
# 22:55:42.35 2332 |     if isinstance(obj, functools.partial):
# 22:55:42.35 2336 |     sig = None
# 22:55:42.35 2337 |     if isinstance(obj, type):
# 22:55:42.35 2342 |         call = _signature_get_user_defined_method(type(obj), '__call__')
# 22:55:42.35 .............. call = None
# 22:55:42.35 2343 |         if call is not None:
# 22:55:42.35 2346 |             factory_method = None
# 22:55:42.35 2347 |             new = _signature_get_user_defined_method(obj, '__new__')
# 22:55:42.36 .................. new = <function Base.__new__ at 0x12747a0d0>
# 22:55:42.36 2348 |             init = _signature_get_user_defined_method(obj, '__init__')
# 22:55:42.36 .................. init = <function Foo_new.__init__ at 0x12747a160>
# 22:55:42.36 2350 |             if '__new__' in obj.__dict__:
# 22:55:42.36 2353 |             elif '__init__' in obj.__dict__:
# 22:55:42.36 2354 |                 factory_method = init
# 22:55:42.36 ...................... factory_method = <function Foo_new.__init__ at 0x12747a160>
# 22:55:42.36 2361 |             if factory_method is not None:
# 22:55:42.36 2362 |                 sig = _get_signature_of(factory_method)
#     22:55:42.36 >>> Call to _signature_from_callable in File "/Users/Natsume/mambaforge/lib/python3.9/inspect.py", line 2246
#     22:55:42.36 ...... obj = <function Foo_new.__init__ at 0x12747a160>
#     22:55:42.36 ...... follow_wrapper_chains = True
#     22:55:42.36 ...... skip_bound_arg = True
#     22:55:42.36 ...... sigcls = <class 'inspect.Signature'>
#     22:55:42.36 2246 | def _signature_from_callable(obj, *,
#     22:55:42.36 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
#     22:55:42.36 2256 |                                 follow_wrapper_chains=follow_wrapper_chains,
#     22:55:42.36 2257 |                                 skip_bound_arg=skip_bound_arg,
#     22:55:42.36 2258 |                                 sigcls=sigcls)
#     22:55:42.36 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
#     22:55:42.36 .......... _get_signature_of = functools.partial(<function _signature_from_call...und_arg=True, sigcls=<class 'inspect.Signature'>)
#     22:55:42.36 2260 |     if not callable(obj):
#     22:55:42.36 2263 |     if isinstance(obj, types.MethodType):
#     22:55:42.36 2274 |     if follow_wrapper_chains:
#     22:55:42.36 2275 |         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))
#     22:55:42.36 2276 |         if isinstance(obj, types.MethodType):
#     22:55:42.36 2282 |     try:
#     22:55:42.36 2283 |         sig = obj.__signature__
#     22:55:42.36 !!! AttributeError: 'function' object has no attribute '__signature__'
#     22:55:42.36 !!! When getting attribute: obj.__signature__
#     22:55:42.36 2284 |     except AttributeError:
#     22:55:42.36 2285 |         pass
#     22:55:42.36 2294 |     try:
#     22:55:42.36 2295 |         partialmethod = obj._partialmethod
#     22:55:42.36 !!! AttributeError: 'function' object has no attribute '_partialmethod'
#     22:55:42.36 !!! When getting attribute: obj._partialmethod
#     22:55:42.36 2296 |     except AttributeError:
#     22:55:42.36 2297 |         pass
#     22:55:42.36 2322 |     if isfunction(obj) or _signature_is_functionlike(obj):
#     22:55:42.36 2325 |         return _signature_from_function(sigcls, obj,
#     22:55:42.36 2326 |                                         skip_bound_arg=skip_bound_arg)
#     22:55:42.36 2325 |         return _signature_from_function(sigcls, obj,
#     22:55:42.36 <<< Return value from _signature_from_callable: <Signature (self, d, e, f)>
# 22:55:42.36 2362 |                 sig = _get_signature_of(factory_method)
# 22:55:42.36 ...................... sig = <Signature (self, d, e, f)>
# 22:55:42.36 2364 |         if sig is None:
# 22:55:42.36 2413 |     if sig is not None:
# 22:55:42.36 2416 |         if skip_bound_arg:
# 22:55:42.36 2417 |             return _signature_bound_method(sig)
# 22:55:42.36 <<< Return value from _signature_from_callable: <Signature (d, e, f)>

# %%
fdb.print(part=4)
# Out:
#         else:=============================================================================(99)
#             factory_method = None=========================================================(100)
#             new = _signature_get_user_defined_method(obj, '__new__')======================(101)
#             init = _signature_get_user_defined_method(obj, '__init__')====================(102)
#             # Now we check if the 'obj' class has an own '__new__' method=================(103) # step 2: Foo has no methods on call nor new, but has init
#             if '__new__' in obj.__dict__:=================================================(104)
#                 factory_method = new======================================================(105)
#             # or an own '__init__' method=================================================(106)
#             elif '__init__' in obj.__dict__:==============================================(107)
#                 factory_method = init=====================================================(108)
#             # If not, we take inherited '__new__' or '__init__', if present===============(109)
#             elif new is not None:=========================================================(110)
#                 factory_method = new======================================================(111)
#             elif init is not None:========================================================(112)
#                 factory_method = init=====================================================(113)
#                                                                                                                                                         (114)
#             if factory_method is not None:================================================(115)
#                 sig = _get_signature_of(factory_method)===================================(116) # step 3: init func is taken by _get_signature_of
#                                                                                                                                                         (117)
#         if sig is None:===================================================================(118)
#             # At this point we know, that `obj` is a class, with no user-=================(119)
#             # defined '__init__', '__new__', or class-level '__call__'====================(120)
#                                                                                                                                                         (121)
#             for base in obj.__mro__[:-1]:=================================================(122)
#                 # Since '__text_signature__' is implemented as a==========================(123)
#                 # descriptor that extracts text signature from the========================(124)
#                 # class docstring, if 'obj' is derived from a builtin=====================(125)
#                 # class, its own '__text_signature__' may be 'None'.======================(126)
#                 # Therefore, we go through the MRO (except the last=======================(127)
#                 # class in there, which is 'object') to find the first====================(128)
#                 # class with non-empty text signature.====================================(129)
#                 try:======================================================================(130)
#                     text_sig = base.__text_signature__====================================(131)
#                                                                                                                                      part No.4 out of 6 parts

# %%
fdb.dbprint(104, "Although Foo inherits __new__ from Base, but Foo.__dict__ refuse to have it. \
So, Foo only take sig from its own __init__. therefore it will go back to step 4 to process sig from function __init__", "'__new__' in obj.__dict__", "'__init__' in obj.__dict__", showdbsrc=True)
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ==============================================================     on line 104     ===============================================================
#      with example
# class Base: # pass
#     def __new__(self, **args): pass  # defines a __new__
#
# class Foo_new(Base):
#     def __init__(self, d, e, f): pass
#
# inspect._signature_from_callable(Foo_new, sigcls=inspect.Signature)
#
#
#             init = _signature_get_user_defined_method(obj, '__init__')                                                                                  (102)
#             # Now we check if the 'obj' class has an own '__new__' method                                                                               (103)
#             if '__new__' in obj.__dict__:===============================================================================================================(104)
# Although Foo inherits __new__ from Base, but Foo.__dict__ refuse to have it. So, Foo only take sig from its own __init__. therefore it will go back to step 4 to process sig from function __init__
#                 factory_method = new                                                                                                                    (105)
#             # or an own '__init__' method                                                                                                               (106)
# print selected srcline with expands above--------
# showdbsrc=Start----------------------------------
# def _signature_from_callable(obj, *,--------------------------------------------------------------------------------------------------------------------(0)
#                              follow_wrapper_chains=True,------------------------------------------------------------------------------------------------(1)
#                              skip_bound_arg=True,-------------------------------------------------------------------------------------------------------(2)
#                              sigcls):-------------------------------------------------------------------------------------------------------------------(3)
#                                                                                                                                                         (4)
#     """Private helper function to get signature for arbitrary-------------------------------------------------------------------------------------------(5)
#     callable objects.-----------------------------------------------------------------------------------------------------------------------------------(6)
#     """-------------------------------------------------------------------------------------------------------------------------------------------------(7)
#                                                                                                                                                         (8)
#     _get_signature_of = functools.partial(_signature_from_callable,-------------------------------------------------------------------------------------(9)
#                                 follow_wrapper_chains=follow_wrapper_chains,----------------------------------------------------------------------------(10)
#                                 skip_bound_arg=skip_bound_arg,------------------------------------------------------------------------------------------(11)
#                                 sigcls=sigcls)----------------------------------------------------------------------------------------------------------(12)
#                                                                                                                                                         (13)
#     if not callable(obj):-------------------------------------------------------------------------------------------------------------------------------(14)
#         raise TypeError('{!r} is not a callable object'.format(obj))------------------------------------------------------------------------------------(15)
#                                                                                                                                                         (16)
#     if isinstance(obj, types.MethodType):---------------------------------------------------------------------------------------------------------------(17)
#         # In this case we skip the first parameter of the underlying------------------------------------------------------------------------------------(18)
#         # function (usually `self` or `cls`).-----------------------------------------------------------------------------------------------------------(19)
#         sig = _get_signature_of(obj.__func__)-----------------------------------------------------------------------------------------------------------(20)
#                                                                                                                                                         (21)
#         if skip_bound_arg:------------------------------------------------------------------------------------------------------------------------------(22)
#             return _signature_bound_method(sig)---------------------------------------------------------------------------------------------------------(23)
#         else:-------------------------------------------------------------------------------------------------------------------------------------------(24)
#             return sig----------------------------------------------------------------------------------------------------------------------------------(25)
#                                                                                                                                                         (26)
#     # Was this function wrapped by a decorator?---------------------------------------------------------------------------------------------------------(27)
#     if follow_wrapper_chains:---------------------------------------------------------------------------------------------------------------------------(28)
#         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))---------------------------------------------------------------------------------(29)
#         if isinstance(obj, types.MethodType):-----------------------------------------------------------------------------------------------------------(30)
#             # If the unwrapped object is a *method*, we might want to-----------------------------------------------------------------------------------(31)
#             # skip its first parameter (self).----------------------------------------------------------------------------------------------------------(32)
#             # See test_signature_wrapped_bound_method for details.--------------------------------------------------------------------------------------(33)
#             return _get_signature_of(obj)---------------------------------------------------------------------------------------------------------------(34)
#                                                                                                                                                         (35)
#     try:------------------------------------------------------------------------------------------------------------------------------------------------(36)
#         sig = obj.__signature__-------------------------------------------------------------------------------------------------------------------------(37)
#     except AttributeError:------------------------------------------------------------------------------------------------------------------------------(38)
#         pass--------------------------------------------------------------------------------------------------------------------------------------------(39)
#     else:-----------------------------------------------------------------------------------------------------------------------------------------------(40)
#         if sig is not None:-----------------------------------------------------------------------------------------------------------------------------(41)
#             if not isinstance(sig, Signature):----------------------------------------------------------------------------------------------------------(42)
#                 raise TypeError(------------------------------------------------------------------------------------------------------------------------(43)
#                     'unexpected object {!r} in __signature__ '------------------------------------------------------------------------------------------(44)
#                     'attribute'.format(sig))------------------------------------------------------------------------------------------------------------(45)
#             return sig----------------------------------------------------------------------------------------------------------------------------------(46)
#                                                                                                                                                         (47)
#     try:------------------------------------------------------------------------------------------------------------------------------------------------(48)
#         partialmethod = obj._partialmethod--------------------------------------------------------------------------------------------------------------(49)
#     except AttributeError:------------------------------------------------------------------------------------------------------------------------------(50)
#         pass--------------------------------------------------------------------------------------------------------------------------------------------(51)
#     else:-----------------------------------------------------------------------------------------------------------------------------------------------(52)
#         if isinstance(partialmethod, functools.partialmethod):------------------------------------------------------------------------------------------(53)
#             # Unbound partialmethod (see functools.partialmethod)---------------------------------------------------------------------------------------(54)
#             # This means, that we need to calculate the signature---------------------------------------------------------------------------------------(55)
#             # as if it's a regular partial object, but taking into--------------------------------------------------------------------------------------(56)
#             # account that the first positional argument------------------------------------------------------------------------------------------------(57)
#             # (usually `self`, or `cls`) will not be passed---------------------------------------------------------------------------------------------(58)
#             # automatically (as for boundmethods)-------------------------------------------------------------------------------------------------------(59)
#                                                                                                                                                         (60)
#             wrapped_sig = _get_signature_of(partialmethod.func)-----------------------------------------------------------------------------------------(61)
#                                                                                                                                                         (62)
#             sig = _signature_get_partial(wrapped_sig, partialmethod, (None,))---------------------------------------------------------------------------(63)
#             first_wrapped_param = tuple(wrapped_sig.parameters.values())[0]-----------------------------------------------------------------------------(64)
#             if first_wrapped_param.kind is Parameter.VAR_POSITIONAL:------------------------------------------------------------------------------------(65)
#                 # First argument of the wrapped callable is `*args`, as in------------------------------------------------------------------------------(66)
#                 # `partialmethod(lambda *args)`.--------------------------------------------------------------------------------------------------------(67)
#                 return sig------------------------------------------------------------------------------------------------------------------------------(68)
#             else:---------------------------------------------------------------------------------------------------------------------------------------(69)
#                 sig_params = tuple(sig.parameters.values())---------------------------------------------------------------------------------------------(70)
#                 assert (not sig_params or---------------------------------------------------------------------------------------------------------------(71)
#                         first_wrapped_param is not sig_params[0])---------------------------------------------------------------------------------------(72)
#                 new_params = (first_wrapped_param,) + sig_params----------------------------------------------------------------------------------------(73)
#                 return sig.replace(parameters=new_params)-----------------------------------------------------------------------------------------------(74)
#                                                                                                                                                         (75)
#     if isfunction(obj) or _signature_is_functionlike(obj):----------------------------------------------------------------------------------------------(76)
#         # If it's a pure Python function, or an object that is duck type--------------------------------------------------------------------------------(77)
#         # of a Python function (Cython functions, for instance), then:----------------------------------------------------------------------------------(78)
#         return _signature_from_function(sigcls, obj,----------------------------------------------------------------------------------------------------(79)
#                                         skip_bound_arg=skip_bound_arg)----------------------------------------------------------------------------------(80)
#                                                                                                                                                         (81)
#     if _signature_is_builtin(obj):----------------------------------------------------------------------------------------------------------------------(82)
#         return _signature_from_builtin(sigcls, obj,-----------------------------------------------------------------------------------------------------(83)
#                                        skip_bound_arg=skip_bound_arg)-----------------------------------------------------------------------------------(84)
#                                                                                                                                                         (85)
#     if isinstance(obj, functools.partial):--------------------------------------------------------------------------------------------------------------(86)
#         wrapped_sig = _get_signature_of(obj.func)-------------------------------------------------------------------------------------------------------(87)
#         return _signature_get_partial(wrapped_sig, obj)-------------------------------------------------------------------------------------------------(88)
#                                                                                                                                                         (89)
#     sig = None------------------------------------------------------------------------------------------------------------------------------------------(90)
#     if isinstance(obj, type):---------------------------------------------------------------------------------------------------------------------------(91)
#         # obj is a class or a metaclass-----------------------------------------------------------------------------------------------------------------(92)
#                                                                                                                                                         (93)
#         # First, let's see if it has an overloaded __call__ defined-------------------------------------------------------------------------------------(94)
#         # in its metaclass------------------------------------------------------------------------------------------------------------------------------(95)
#         call = _signature_get_user_defined_method(type(obj), '__call__')--------------------------------------------------------------------------------(96)
#         if call is not None:----------------------------------------------------------------------------------------------------------------------------(97)
#             sig = _get_signature_of(call)---------------------------------------------------------------------------------------------------------------(98)
#         else:-------------------------------------------------------------------------------------------------------------------------------------------(99)
#             factory_method = None-----------------------------------------------------------------------------------------------------------------------(100)
#             new = _signature_get_user_defined_method(obj, '__new__')------------------------------------------------------------------------------------(101)
#             init = _signature_get_user_defined_method(obj, '__init__')----------------------------------------------------------------------------------(102)
#             # Now we check if the 'obj' class has an own '__new__' method-------------------------------------------------------------------------------(103)
#             print()=====================================================================================================================================(db)
#             print('{:=>157}'.format(colorize('Start of my srcline exploration:', color='r')))===========================================================(db)
#             g = locals()================================================================================================================================(db)
#             dbprintinsert("'__new__' in obj.__dict__","'__init__' in obj.__dict__",env=g)===============================================================(db)
#             print('{:=>157}'.format(colorize('End of my srcline exploration:', color='r')))=============================================================(db)
#             print()=====================================================================================================================================(db)
#             if '__new__' in obj.__dict__:---------------------------------------------------------------------------------------------------------------(104)
#                 factory_method = new--------------------------------------------------------------------------------------------------------------------(105)
#             # or an own '__init__' method---------------------------------------------------------------------------------------------------------------(106)
#             elif '__init__' in obj.__dict__:------------------------------------------------------------------------------------------------------------(107)
#                 factory_method = init-------------------------------------------------------------------------------------------------------------------(108)
#             # If not, we take inherited '__new__' or '__init__', if present-----------------------------------------------------------------------------(109)
#             elif new is not None:-----------------------------------------------------------------------------------------------------------------------(110)
#                 factory_method = new--------------------------------------------------------------------------------------------------------------------(111)
#             elif init is not None:----------------------------------------------------------------------------------------------------------------------(112)
#                 factory_method = init-------------------------------------------------------------------------------------------------------------------(113)
#                                                                                                                                                         (114)
#             if factory_method is not None:--------------------------------------------------------------------------------------------------------------(115)
#                 sig = _get_signature_of(factory_method)-------------------------------------------------------------------------------------------------(116)
#                                                                                                                                                         (117)
#         if sig is None:---------------------------------------------------------------------------------------------------------------------------------(118)
#             # At this point we know, that `obj` is a class, with no user--------------------------------------------------------------------------------(119)
#             # defined '__init__', '__new__', or class-level '__call__'----------------------------------------------------------------------------------(120)
#                                                                                                                                                         (121)
#             for base in obj.__mro__[:-1]:---------------------------------------------------------------------------------------------------------------(122)
#                 # Since '__text_signature__' is implemented as a----------------------------------------------------------------------------------------(123)
#                 # descriptor that extracts text signature from the--------------------------------------------------------------------------------------(124)
#                 # class docstring, if 'obj' is derived from a builtin-----------------------------------------------------------------------------------(125)
#                 # class, its own '__text_signature__' may be 'None'.------------------------------------------------------------------------------------(126)
#                 # Therefore, we go through the MRO (except the last-------------------------------------------------------------------------------------(127)
#                 # class in there, which is 'object') to find the first----------------------------------------------------------------------------------(128)
#                 # class with non-empty text signature.--------------------------------------------------------------------------------------------------(129)
#                 try:------------------------------------------------------------------------------------------------------------------------------------(130)
#                     text_sig = base.__text_signature__--------------------------------------------------------------------------------------------------(131)
#                 except AttributeError:------------------------------------------------------------------------------------------------------------------(132)
#                     pass--------------------------------------------------------------------------------------------------------------------------------(133)
#                 else:-----------------------------------------------------------------------------------------------------------------------------------(134)
#                     if text_sig:------------------------------------------------------------------------------------------------------------------------(135)
#                         # If 'base' class has a __text_signature__ attribute:---------------------------------------------------------------------------(136)
#                         # return a signature based on it------------------------------------------------------------------------------------------------(137)
#                         return _signature_fromstr(sigcls, base, text_sig)-------------------------------------------------------------------------------(138)
#                                                                                                                                                         (139)
#             # No '__text_signature__' was found for the 'obj' class.------------------------------------------------------------------------------------(140)
#             # Last option is to check if its '__init__' is----------------------------------------------------------------------------------------------(141)
#             # object.__init__ or type.__init__.---------------------------------------------------------------------------------------------------------(142)
#             if type not in obj.__mro__:-----------------------------------------------------------------------------------------------------------------(143)
#                 # We have a class (not metaclass), but no user-defined----------------------------------------------------------------------------------(144)
#                 # __init__ or __new__ for it------------------------------------------------------------------------------------------------------------(145)
#                 if (obj.__init__ is object.__init__ and-------------------------------------------------------------------------------------------------(146)
#                     obj.__new__ is object.__new__):-----------------------------------------------------------------------------------------------------(147)
#                     # Return a signature of 'object' builtin.-------------------------------------------------------------------------------------------(148)
#                     return sigcls.from_callable(object)-------------------------------------------------------------------------------------------------(149)
#                 else:-----------------------------------------------------------------------------------------------------------------------------------(150)
#                     raise ValueError(-------------------------------------------------------------------------------------------------------------------(151)
#                         'no signature found for builtin type {!r}'.format(obj))-------------------------------------------------------------------------(152)
#                                                                                                                                                         (153)
#     elif not isinstance(obj, _NonUserDefinedCallables):-------------------------------------------------------------------------------------------------(154)
#         # An object with __call__-----------------------------------------------------------------------------------------------------------------------(155)
#         # We also check that the 'obj' is not an instance of--------------------------------------------------------------------------------------------(156)
#         # _WrapperDescriptor or _MethodWrapper to avoid-------------------------------------------------------------------------------------------------(157)
#         # infinite recursion (and even potential segfault)----------------------------------------------------------------------------------------------(158)
#         call = _signature_get_user_defined_method(type(obj), '__call__')--------------------------------------------------------------------------------(159)
#         if call is not None:----------------------------------------------------------------------------------------------------------------------------(160)
#             try:----------------------------------------------------------------------------------------------------------------------------------------(161)
#                 sig = _get_signature_of(call)-----------------------------------------------------------------------------------------------------------(162)
#             except ValueError as ex:--------------------------------------------------------------------------------------------------------------------(163)
#                 msg = 'no signature found for {!r}'.format(obj)-----------------------------------------------------------------------------------------(164)
#                 raise ValueError(msg) from ex-----------------------------------------------------------------------------------------------------------(165)
#                                                                                                                                                         (166)
#     if sig is not None:---------------------------------------------------------------------------------------------------------------------------------(167)
#         # For classes and objects we skip the first parameter of their----------------------------------------------------------------------------------(168)
#         # __call__, __new__, or __init__ methods--------------------------------------------------------------------------------------------------------(169)
#         if skip_bound_arg:------------------------------------------------------------------------------------------------------------------------------(170)
#             return _signature_bound_method(sig)---------------------------------------------------------------------------------------------------------(171)
#         else:-------------------------------------------------------------------------------------------------------------------------------------------(172)
#             return sig----------------------------------------------------------------------------------------------------------------------------------(173)
#                                                                                                                                                         (174)
#     if isinstance(obj, types.BuiltinFunctionType):------------------------------------------------------------------------------------------------------(175)
#         # Raise a nicer error message for builtins------------------------------------------------------------------------------------------------------(176)
#         msg = 'no signature found for builtin function {!r}'.format(obj)--------------------------------------------------------------------------------(177)
#         raise ValueError(msg)---------------------------------------------------------------------------------------------------------------------------(178)
#                                                                                                                                                         (179)
#     raise ValueError('callable {!r} is not supported by signature'.format(obj))-------------------------------------------------------------------------(180)
# locals() keys: ['self', 'idxsrc', 'cmt', 'expand', 'showdbsrc', 'codes', 'src', 'dbsrc', 'indent', 'lst', 'newlst', 'i', 'srclines', 'idx', 'l', 'numindent', 'dbcodes', 'count', 'c', 'emptyline', 'exploreStart', 'exploreEnd', 'totallen', 'lenidx', 'dblst', 'idxsrcline', 'lenl']
# before exec, self.orisrc.__name__: _signature_from_callable is : <function _signature_from_callable at 0x1013624c0>
# exec on dbsrc above------------------------------
# locals() keys: ['self', 'idxsrc', 'cmt', 'expand', 'showdbsrc', 'codes', 'src', 'dbsrc', 'indent', 'lst', 'newlst', 'i', 'srclines', 'idx', 'l', 'numindent', 'dbcodes', 'count', 'c', 'emptyline', 'exploreStart', 'exploreEnd', 'totallen', 'lenidx', 'dblst', 'idxsrcline', 'lenl', 'names', '_signature_from_callable']
# self.orisrc.__name__: _signature_from_callable
# locals()['_signature_from_callable']: <function _signature_from_callable at 0x127434670>
# inspect.getsourcefile(locals()['_signature_from_callable)): <string>
# after exec and before self.outenv update, self.orisrc.__name__: _signature_from_callable is locals()['_signature_from_callable']: False
# after update self.outenv, self.orisrc.__name__: _signature_from_callable is self.outenv['_signature_from_callable']: False
# after update self.outenv, self.orisrc.__name__: _signature_from_callable is inspect._signature_from_callable: False
# after update self.outenv, self.outenv['_signature_from_callable'] is inspect._signature_from_callable: True
# Therefore, to use dbsrc we must use self.outenv['_signature_from_callable'], or inspect._signature_from_callable
# showdbsrc=End------------------------------------
#
# ==================================================================================================================Start of my srcline exploration:
#
#
#                                                                                                '__new__' in obj.__dict__ => '__new__' in obj.__dict__ : False
#
#
#                                                                                               '__init__' in obj.__dict__ => '__init__' in obj.__dict__ : True
# ====================================================================================================================End of my srcline exploration:
#
# <Signature (d, e, f)>
#
# Review srcode with all comments added so far======================================================================================================
#         else:=============================================================================(99)
#             factory_method = None=========================================================(100)
#             new = _signature_get_user_defined_method(obj, '__new__')======================(101)
#             init = _signature_get_user_defined_method(obj, '__init__')====================(102)
#             # Now we check if the 'obj' class has an own '__new__' method=================(103) # step 2: Foo has no methods on call nor new, but has init
#             if '__new__' in obj.__dict__:=================================================(104) # step 5: Although Foo inherits __new__ from Base, but Foo.__dict__ refuse to have it. So, Foo only take sig from its own __init__. therefore it will go back to step 4 to process sig from function __init__
#                 factory_method = new======================================================(105)
#             # or an own '__init__' method=================================================(106)
#             elif '__init__' in obj.__dict__:==============================================(107)
#                 factory_method = init=====================================================(108)
#             # If not, we take inherited '__new__' or '__init__', if present===============(109)
#             elif new is not None:=========================================================(110)
#                 factory_method = new======================================================(111)
#             elif init is not None:========================================================(112)
#                 factory_method = init=====================================================(113)
#                                                                                                                                                         (114)
#             if factory_method is not None:================================================(115)
#                 sig = _get_signature_of(factory_method)===================================(116) # step 3: init func is taken by _get_signature_of
#                                                                                                                                                         (117)
#         if sig is None:===================================================================(118)
#             # At this point we know, that `obj` is a class, with no user-=================(119)
#             # defined '__init__', '__new__', or class-level '__call__'====================(120)
#                                                                                                                                                         (121)
#             for base in obj.__mro__[:-1]:=================================================(122)
#                 # Since '__text_signature__' is implemented as a==========================(123)
#                 # descriptor that extracts text signature from the========================(124)
#                 # class docstring, if 'obj' is derived from a builtin=====================(125)
#                 # class, its own '__text_signature__' may be 'None'.======================(126)
#                 # Therefore, we go through the MRO (except the last=======================(127)
#                 # class in there, which is 'object') to find the first====================(128)
#                 # class with non-empty text signature.====================================(129)
#                 try:======================================================================(130)
#                     text_sig = base.__text_signature__====================================(131)
#                                                                                                                                      part No.4 out of 6 parts
# <function inspect._signature_from_callable(obj, *, follow_wrapper_chains=True, skip_bound_arg=True, sigcls)>

# %%
fdb.print()
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ==============================================================     on line 104     ===============================================================
#      with example
# class Base: # pass
#     def __new__(self, **args): pass  # defines a __new__
#
# class Foo_new(Base):
#     def __init__(self, d, e, f): pass
#
# inspect._signature_from_callable(Foo_new, sigcls=inspect.Signature)
#
#
# def _signature_from_callable(obj, *,======================================================(0)
#                              follow_wrapper_chains=True,==================================(1)
#                              skip_bound_arg=True,=========================================(2)
#                              sigcls):=====================================================(3)
#                                                                                                                                                         (4)
#     """Private helper function to get signature for arbitrary=============================(5)
#     callable objects.=====================================================================(6)
#     """===================================================================================(7)
#                                                                                                                                                         (8)
#     _get_signature_of = functools.partial(_signature_from_callable,=======================(9)
#                                 follow_wrapper_chains=follow_wrapper_chains,==============(10)
#                                 skip_bound_arg=skip_bound_arg,============================(11)
#                                 sigcls=sigcls)============================================(12)
#                                                                                                                                                         (13)
#     if not callable(obj):=================================================================(14)
#         raise TypeError('{!r} is not a callable object'.format(obj))======================(15)
#                                                                                                                                                         (16)
#     if isinstance(obj, types.MethodType):=================================================(17)
#         # In this case we skip the first parameter of the underlying======================(18)
#         # function (usually `self` or `cls`).=============================================(19)
#         sig = _get_signature_of(obj.__func__)=============================================(20)
#                                                                                                                                                         (21)
#         if skip_bound_arg:================================================================(22)
#             return _signature_bound_method(sig)===========================================(23)
#         else:=============================================================================(24)
#             return sig====================================================================(25)
#                                                                                                                                                         (26)
#     # Was this function wrapped by a decorator?===========================================(27)
#     if follow_wrapper_chains:=============================================================(28)
#         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))===================(29)
#         if isinstance(obj, types.MethodType):=============================================(30)
#             # If the unwrapped object is a *method*, we might want to=====================(31)
#             # skip its first parameter (self).============================================(32)
#             # See test_signature_wrapped_bound_method for details.========================(33)
#             return _get_signature_of(obj)=================================================(34)
#                                                                                                                                                         (35)
#     try:==================================================================================(36)
#         sig = obj.__signature__===========================================================(37)
#     except AttributeError:================================================================(38)
#         pass==============================================================================(39)
#     else:=================================================================================(40)
#         if sig is not None:===============================================================(41)
#             if not isinstance(sig, Signature):============================================(42)
#                 raise TypeError(==========================================================(43)
#                     'unexpected object {!r} in __signature__ '============================(44)
#                     'attribute'.format(sig))==============================================(45)
#             return sig====================================================================(46)
#                                                                                                                                                         (47)
#     try:==================================================================================(48)
#         partialmethod = obj._partialmethod================================================(49)
#     except AttributeError:================================================================(50)
#         pass==============================================================================(51)
#     else:=================================================================================(52)
#         if isinstance(partialmethod, functools.partialmethod):============================(53)
#             # Unbound partialmethod (see functools.partialmethod)=========================(54)
#             # This means, that we need to calculate the signature=========================(55)
#             # as if it's a regular partial object, but taking into========================(56)
#             # account that the first positional argument==================================(57)
#             # (usually `self`, or `cls`) will not be passed===============================(58)
#             # automatically (as for boundmethods)=========================================(59)
#                                                                                                                                                         (60)
#             wrapped_sig = _get_signature_of(partialmethod.func)===========================(61)
#                                                                                                                                                         (62)
#             sig = _signature_get_partial(wrapped_sig, partialmethod, (None,))=============(63)
#             first_wrapped_param = tuple(wrapped_sig.parameters.values())[0]===============(64)
#             if first_wrapped_param.kind is Parameter.VAR_POSITIONAL:======================(65)
#                 # First argument of the wrapped callable is `*args`, as in================(66)
#                 # `partialmethod(lambda *args)`.==========================================(67)
#                 return sig================================================================(68)
#             else:=========================================================================(69)
#                 sig_params = tuple(sig.parameters.values())===============================(70)
#                 assert (not sig_params or=================================================(71)
#                         first_wrapped_param is not sig_params[0])=========================(72)
#                 new_params = (first_wrapped_param,) + sig_params==========================(73)
#                 return sig.replace(parameters=new_params)=================================(74)
#                                                                                                                                                         (75)
#     if isfunction(obj) or _signature_is_functionlike(obj):================================(76) # step 0: whatinside's sig is finally processed by _signature_from_function
#         # If it's a pure Python function, or an object that is duck type==================(77) # step 4: init func will be processed by _signature_from_function in the block above. see explorations below:
#         # of a Python function (Cython functions, for instance), then:====================(78)
#         return _signature_from_function(sigcls, obj,======================================(79)
#                                         skip_bound_arg=skip_bound_arg)====================(80)
#                                                                                                                                                         (81)
#     if _signature_is_builtin(obj):========================================================(82)
#         return _signature_from_builtin(sigcls, obj,=======================================(83)
#                                        skip_bound_arg=skip_bound_arg)=====================(84)
#                                                                                                                                                         (85)
#     if isinstance(obj, functools.partial):================================================(86)
#         wrapped_sig = _get_signature_of(obj.func)=========================================(87)
#         return _signature_get_partial(wrapped_sig, obj)===================================(88)
#                                                                                                                                                         (89)
#     sig = None============================================================================(90)
#     if isinstance(obj, type):=============================================================(91) # step 1: Foo is taken care of in this if block
#         # obj is a class or a metaclass===================================================(92)
#                                                                                                                                                         (93)
#         # First, let's see if it has an overloaded __call__ defined=======================(94)
#         # in its metaclass================================================================(95)
#         call = _signature_get_user_defined_method(type(obj), '__call__')==================(96)
#         if call is not None:==============================================================(97)
#             sig = _get_signature_of(call)=================================================(98)
#         else:=============================================================================(99)
#             factory_method = None=========================================================(100)
#             new = _signature_get_user_defined_method(obj, '__new__')======================(101)
#             init = _signature_get_user_defined_method(obj, '__init__')====================(102)
#             # Now we check if the 'obj' class has an own '__new__' method=================(103) # step 2: Foo has no methods on call nor new, but has init
#             if '__new__' in obj.__dict__:=================================================(104) # step 5: Although Foo inherits __new__ from Base, but Foo.__dict__ refuse to have it. So, Foo only take sig from its own __init__. therefore it will go back to step 4 to process sig from function __init__
#                 factory_method = new======================================================(105)
#             # or an own '__init__' method=================================================(106)
#             elif '__init__' in obj.__dict__:==============================================(107)
#                 factory_method = init=====================================================(108)
#             # If not, we take inherited '__new__' or '__init__', if present===============(109)
#             elif new is not None:=========================================================(110)
#                 factory_method = new======================================================(111)
#             elif init is not None:========================================================(112)
#                 factory_method = init=====================================================(113)
#                                                                                                                                                         (114)
#             if factory_method is not None:================================================(115)
#                 sig = _get_signature_of(factory_method)===================================(116) # step 3: init func is taken by _get_signature_of
#                                                                                                                                                         (117)
#         if sig is None:===================================================================(118)
#             # At this point we know, that `obj` is a class, with no user-=================(119)
#             # defined '__init__', '__new__', or class-level '__call__'====================(120)
#                                                                                                                                                         (121)
#             for base in obj.__mro__[:-1]:=================================================(122)
#                 # Since '__text_signature__' is implemented as a==========================(123)
#                 # descriptor that extracts text signature from the========================(124)
#                 # class docstring, if 'obj' is derived from a builtin=====================(125)
#                 # class, its own '__text_signature__' may be 'None'.======================(126)
#                 # Therefore, we go through the MRO (except the last=======================(127)
#                 # class in there, which is 'object') to find the first====================(128)
#                 # class with non-empty text signature.====================================(129)
#                 try:======================================================================(130)
#                     text_sig = base.__text_signature__====================================(131)
#                 except AttributeError:====================================================(132)
#                     pass==================================================================(133)
#                 else:=====================================================================(134)
#                     if text_sig:==========================================================(135)
#                         # If 'base' class has a __text_signature__ attribute:=============(136)
#                         # return a signature based on it==================================(137)
#                         return _signature_fromstr(sigcls, base, text_sig)=================(138)
#                                                                                                                                                         (139)
#             # No '__text_signature__' was found for the 'obj' class.======================(140)
#             # Last option is to check if its '__init__' is================================(141)
#             # object.__init__ or type.__init__.===========================================(142)
#             if type not in obj.__mro__:===================================================(143)
#                 # We have a class (not metaclass), but no user-defined====================(144)
#                 # __init__ or __new__ for it==============================================(145)
#                 if (obj.__init__ is object.__init__ and===================================(146)
#                     obj.__new__ is object.__new__):=======================================(147)
#                     # Return a signature of 'object' builtin.=============================(148)
#                     return sigcls.from_callable(object)===================================(149)
#                 else:=====================================================================(150)
#                     raise ValueError(=====================================================(151)
#                         'no signature found for builtin type {!r}'.format(obj))===========(152)
#                                                                                                                                                         (153)
#     elif not isinstance(obj, _NonUserDefinedCallables):===================================(154)
#         # An object with __call__=========================================================(155)
#         # We also check that the 'obj' is not an instance of==============================(156)
#         # _WrapperDescriptor or _MethodWrapper to avoid===================================(157)
#         # infinite recursion (and even potential segfault)================================(158)
#         call = _signature_get_user_defined_method(type(obj), '__call__')==================(159)
#         if call is not None:==============================================================(160)
#             try:==========================================================================(161)
#                 sig = _get_signature_of(call)=============================================(162)
#             except ValueError as ex:======================================================(163)
#                 msg = 'no signature found for {!r}'.format(obj)===========================(164)
#                 raise ValueError(msg) from ex=============================================(165)
#                                                                                                                                                         (166)
#     if sig is not None:===================================================================(167)
#         # For classes and objects we skip the first parameter of their====================(168)
#         # __call__, __new__, or __init__ methods==========================================(169)
#         if skip_bound_arg:================================================================(170)
#             return _signature_bound_method(sig)===========================================(171)
#         else:=============================================================================(172)
#             return sig====================================================================(173)
#                                                                                                                                                         (174)
#     if isinstance(obj, types.BuiltinFunctionType):========================================(175)
#         # Raise a nicer error message for builtins========================================(176)
#         msg = 'no signature found for builtin function {!r}'.format(obj)==================(177)
#         raise ValueError(msg)=============================================================(178)
#                                                                                                                                                         (179)
#     raise ValueError('callable {!r} is not supported by signature'.format(obj))===========(180)
#                                                                                                                                                         (181)

# %%
from fastcore.meta import *

# %%
class Base: # pass
    def __new__(self, **args): pass  # defines a __new__ 

class Foo_new_fix(Base, metaclass=FixSigMeta):
    def __init__(self, d, e, f): pass
    
inspect._signature_from_callable(Foo_new_fix, sigcls=inspect.Signature)
# Out:
# <Signature (d, e, f)>

# %%
example = """
class Base: # pass
    def __new__(self, **args): pass  # defines a __new__ 

class Foo_new_fix(Base, metaclass=FixSigMeta):
    def __init__(self, d, e, f): pass
    
inspect._signature_from_callable(Foo_new_fix, sigcls=inspect.Signature)
"""

# %%
fdb.takExample(example, Foo_new_fix=Foo_new_fix, inspect=inspect)

# %%
fdb.snoop()
# Out:
# 22:55:42.40 >>> Call to _signature_from_callable in File "/Users/Natsume/mambaforge/lib/python3.9/inspect.py", line 2246
# 22:55:42.40 ...... obj = <class '__main__.Foo_new_fix'>
# 22:55:42.40 ...... follow_wrapper_chains = True
# 22:55:42.40 ...... skip_bound_arg = True
# 22:55:42.40 ...... sigcls = <class 'inspect.Signature'>
# 22:55:42.40 2246 | def _signature_from_callable(obj, *,
# 22:55:42.41 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:42.41 2256 |                                 follow_wrapper_chains=follow_wrapper_chains,
# 22:55:42.41 2257 |                                 skip_bound_arg=skip_bound_arg,
# 22:55:42.41 2258 |                                 sigcls=sigcls)
# 22:55:42.41 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:42.41 .......... _get_signature_of = functools.partial(<function _signature_from_call...und_arg=True, sigcls=<class 'inspect.Signature'>)
# 22:55:42.41 2260 |     if not callable(obj):
# 22:55:42.41 2263 |     if isinstance(obj, types.MethodType):
# 22:55:42.41 2274 |     if follow_wrapper_chains:
# 22:55:42.41 2275 |         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))
# 22:55:42.41 2276 |         if isinstance(obj, types.MethodType):
# 22:55:42.41 2282 |     try:
# 22:55:42.41 2283 |         sig = obj.__signature__
# 22:55:42.41 .............. sig = <Signature (d, e, f)>
# 22:55:42.41 2287 |         if sig is not None:
# 22:55:42.41 2288 |             if not isinstance(sig, Signature):
# 22:55:42.41 2292 |             return sig
# 22:55:42.41 <<< Return value from _signature_from_callable: <Signature (d, e, f)>

# %%
fdb.dbprint(29, "Every obj must be unwrapped if wrapped, unless it has __signature__", "obj", "obj = unwrap(obj)", \
            "obj = unwrap(obj, stop=(lambda f: hasattr(f, '__signature__')))", "inspect.getdoc(unwrap)")
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ===============================================================     on line 29     ===============================================================
#      with example
# class Base: # pass
#     def __new__(self, **args): pass  # defines a __new__
#
# class Foo_new_fix(Base, metaclass=FixSigMeta):
#     def __init__(self, d, e, f): pass
#
# inspect._signature_from_callable(Foo_new_fix, sigcls=inspect.Signature)
#
#
#     # Was this function wrapped by a decorator?                                                                                                         (27)
#     if follow_wrapper_chains:                                                                                                                           (28)
#         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))=================================================================================(29)
#                                                                                           Every obj must be unwrapped if wrapped, unless it has __signature__
#         if isinstance(obj, types.MethodType):                                                                                                           (30)
#             # If the unwrapped object is a *method*, we might want to                                                                                   (31)
#
# ==================================================================================================================Start of my srcline exploration:
#
#
#                                                                                                                   obj => obj : <class '__main__.Foo_new_fix'>
#
#
#                                                                                                      obj = unwrap(obj) => obj: <class '__main__.Foo_new_fix'>
#
#
#                                                        obj = unwrap(obj, stop=(lambda f: hasattr(f, '__signature__'))) => obj: <class '__main__.Foo_new_fix'>
#
#
# inspect.getdoc(unwrap) => inspect.getdoc(unwrap) : Get the object wrapped by *func*.
#
# Follows the chain of :attr:`__wrapped__` attributes returning the last
# object in the chain.
#
# *stop* is an optional callback accepting an object in the wrapper chain
# as its sole argument that allows the unwrapping to be terminated early if
# the callback returns a true value. If the callback never returns a true
# value, the last object in the chain is returned as usual. For example,
# :func:`signature` uses this to stop unwrapping if any object in the
# chain has a ``__signature__`` attribute defined.
#
# :exc:`ValueError` is raised if a cycle is encountered.
#
#
# ====================================================================================================================End of my srcline exploration:
#
# <Signature (d, e, f)>
#
# Review srcode with all comments added so far======================================================================================================
# def _signature_from_callable(obj, *,======================================================(0)
#                              follow_wrapper_chains=True,==================================(1)
#                              skip_bound_arg=True,=========================================(2)
#                              sigcls):=====================================================(3)
#                                                                                                                                                         (4)
#     """Private helper function to get signature for arbitrary=============================(5)
#     callable objects.=====================================================================(6)
#     """===================================================================================(7)
#                                                                                                                                                         (8)
#     _get_signature_of = functools.partial(_signature_from_callable,=======================(9)
#                                 follow_wrapper_chains=follow_wrapper_chains,==============(10)
#                                 skip_bound_arg=skip_bound_arg,============================(11)
#                                 sigcls=sigcls)============================================(12)
#                                                                                                                                                         (13)
#     if not callable(obj):=================================================================(14)
#         raise TypeError('{!r} is not a callable object'.format(obj))======================(15)
#                                                                                                                                                         (16)
#     if isinstance(obj, types.MethodType):=================================================(17)
#         # In this case we skip the first parameter of the underlying======================(18)
#         # function (usually `self` or `cls`).=============================================(19)
#         sig = _get_signature_of(obj.__func__)=============================================(20)
#                                                                                                                                                         (21)
#         if skip_bound_arg:================================================================(22)
#             return _signature_bound_method(sig)===========================================(23)
#         else:=============================================================================(24)
#             return sig====================================================================(25)
#                                                                                                                                                         (26)
#     # Was this function wrapped by a decorator?===========================================(27)
#     if follow_wrapper_chains:=============================================================(28)
#         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))===================(29) # step 6: Every obj must be unwrapped if wrapped, unless it has __signature__
#         if isinstance(obj, types.MethodType):=============================================(30)
#             # If the unwrapped object is a *method*, we might want to=====================(31)
#             # skip its first parameter (self).============================================(32)
#                                                                                                                                      part No.1 out of 6 parts
# <function inspect._signature_from_callable(obj, *, follow_wrapper_chains=True, skip_bound_arg=True, sigcls)>

# %%
fdb.dbprint(37, "Every obj must be checked with __signature__, if it has the attr, then use it as sig", )
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ===============================================================     on line 37     ===============================================================
#      with example
# class Base: # pass
#     def __new__(self, **args): pass  # defines a __new__
#
# class Foo_new_fix(Base, metaclass=FixSigMeta):
#     def __init__(self, d, e, f): pass
#
# inspect._signature_from_callable(Foo_new_fix, sigcls=inspect.Signature)
#
#
#                                                                                                                                                         (35)
#     try:                                                                                                                                                (36)
#         sig = obj.__signature__=========================================================================================================================(37)
#                                                                          Every obj must be checked with __signature__, if it has the attr, then use it as sig
#     except AttributeError:                                                                                                                              (38)
#         pass                                                                                                                                            (39)
# <Signature (d, e, f)>
#
# Review srcode with all comments added so far======================================================================================================
#             # See test_signature_wrapped_bound_method for details.========================(33)
#             return _get_signature_of(obj)=================================================(34)
#                                                                                                                                                         (35)
#     try:==================================================================================(36)
#         sig = obj.__signature__===========================================================(37) # step 7: Every obj must be checked with __signature__, if it has the attr, then use it as sig
#     except AttributeError:================================================================(38)
#         pass==============================================================================(39)
#     else:=================================================================================(40)
#         if sig is not None:===============================================================(41)
#             if not isinstance(sig, Signature):============================================(42)
#                 raise TypeError(==========================================================(43)
#                     'unexpected object {!r} in __signature__ '============================(44)
#                     'attribute'.format(sig))==============================================(45)
#             return sig====================================================================(46)
#                                                                                                                                                         (47)
#     try:==================================================================================(48)
#         partialmethod = obj._partialmethod================================================(49)
#     except AttributeError:================================================================(50)
#         pass==============================================================================(51)
#     else:=================================================================================(52)
#         if isinstance(partialmethod, functools.partialmethod):============================(53)
#             # Unbound partialmethod (see functools.partialmethod)=========================(54)
#             # This means, that we need to calculate the signature=========================(55)
#             # as if it's a regular partial object, but taking into========================(56)
#             # account that the first positional argument==================================(57)
#             # (usually `self`, or `cls`) will not be passed===============================(58)
#             # automatically (as for boundmethods)=========================================(59)
#                                                                                                                                                         (60)
#             wrapped_sig = _get_signature_of(partialmethod.func)===========================(61)
#                                                                                                                                                         (62)
#             sig = _signature_get_partial(wrapped_sig, partialmethod, (None,))=============(63)
#             first_wrapped_param = tuple(wrapped_sig.parameters.values())[0]===============(64)
#             if first_wrapped_param.kind is Parameter.VAR_POSITIONAL:======================(65)
#                                                                                                                                      part No.2 out of 6 parts
# <function inspect._signature_from_callable(obj, *, follow_wrapper_chains=True, skip_bound_arg=True, sigcls)>

# %%
class BaseMeta(type): 
    # using __new__ from type
    def __call__(cls, *args, **kwargs): pass
class Foo_call(metaclass=BaseMeta): 
    def __init__(self, d, e, f): pass

inspect._signature_from_callable(Foo_call, sigcls=inspect.Signature)
# Out:
# <Signature (*args, **kwargs)>

# %%
example = """
class BaseMeta(type): 
    # using __new__ from type
    def __call__(cls, *args, **kwargs): pass
class Foo_call(metaclass=BaseMeta): 
    def __init__(self, d, e, f): pass

inspect._signature_from_callable(Foo_call, sigcls=inspect.Signature)
"""

# %%
fdb.takExample(example, Foo_call=Foo_call, inspect=inspect)

# %%
fdb.snoop()
# Out:
# 22:55:42.45 >>> Call to _signature_from_callable in File "/Users/Natsume/mambaforge/lib/python3.9/inspect.py", line 2246
# 22:55:42.45 ...... obj = <class '__main__.Foo_call'>
# 22:55:42.45 ...... follow_wrapper_chains = True
# 22:55:42.45 ...... skip_bound_arg = True
# 22:55:42.45 ...... sigcls = <class 'inspect.Signature'>
# 22:55:42.45 2246 | def _signature_from_callable(obj, *,
# 22:55:42.45 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:42.45 2256 |                                 follow_wrapper_chains=follow_wrapper_chains,
# 22:55:42.45 2257 |                                 skip_bound_arg=skip_bound_arg,
# 22:55:42.45 2258 |                                 sigcls=sigcls)
# 22:55:42.45 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:42.45 .......... _get_signature_of = functools.partial(<function _signature_from_call...und_arg=True, sigcls=<class 'inspect.Signature'>)
# 22:55:42.45 2260 |     if not callable(obj):
# 22:55:42.45 2263 |     if isinstance(obj, types.MethodType):
# 22:55:42.45 2274 |     if follow_wrapper_chains:
# 22:55:42.45 2275 |         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))
# 22:55:42.46 2276 |         if isinstance(obj, types.MethodType):
# 22:55:42.46 2282 |     try:
# 22:55:42.46 2283 |         sig = obj.__signature__
# 22:55:42.46 !!! AttributeError: type object 'Foo_call' has no attribute '__signature__'
# 22:55:42.46 !!! When getting attribute: obj.__signature__
# 22:55:42.46 2284 |     except AttributeError:
# 22:55:42.46 2285 |         pass
# 22:55:42.46 2294 |     try:
# 22:55:42.46 2295 |         partialmethod = obj._partialmethod
# 22:55:42.46 !!! AttributeError: type object 'Foo_call' has no attribute '_partialmethod'
# 22:55:42.46 !!! When getting attribute: obj._partialmethod
# 22:55:42.46 2296 |     except AttributeError:
# 22:55:42.46 2297 |         pass
# 22:55:42.46 2322 |     if isfunction(obj) or _signature_is_functionlike(obj):
# 22:55:42.46 2328 |     if _signature_is_builtin(obj):
# 22:55:42.46 2332 |     if isinstance(obj, functools.partial):
# 22:55:42.46 2336 |     sig = None
# 22:55:42.46 2337 |     if isinstance(obj, type):
# 22:55:42.46 2342 |         call = _signature_get_user_defined_method(type(obj), '__call__')
# 22:55:42.46 .............. call = <function BaseMeta.__call__ at 0x12743cb80>
# 22:55:42.46 2343 |         if call is not None:
# 22:55:42.46 2344 |             sig = _get_signature_of(call)
#     22:55:42.46 >>> Call to _signature_from_callable in File "/Users/Natsume/mambaforge/lib/python3.9/inspect.py", line 2246
#     22:55:42.46 ...... obj = <function BaseMeta.__call__ at 0x12743cb80>
#     22:55:42.46 ...... follow_wrapper_chains = True
#     22:55:42.46 ...... skip_bound_arg = True
#     22:55:42.46 ...... sigcls = <class 'inspect.Signature'>
#     22:55:42.46 2246 | def _signature_from_callable(obj, *,
#     22:55:42.46 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
#     22:55:42.46 2256 |                                 follow_wrapper_chains=follow_wrapper_chains,
#     22:55:42.46 2257 |                                 skip_bound_arg=skip_bound_arg,
#     22:55:42.46 2258 |                                 sigcls=sigcls)
#     22:55:42.46 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
#     22:55:42.46 .......... _get_signature_of = functools.partial(<function _signature_from_call...und_arg=True, sigcls=<class 'inspect.Signature'>)
#     22:55:42.46 2260 |     if not callable(obj):
#     22:55:42.46 2263 |     if isinstance(obj, types.MethodType):
#     22:55:42.46 2274 |     if follow_wrapper_chains:
#     22:55:42.46 2275 |         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))
#     22:55:42.46 2276 |         if isinstance(obj, types.MethodType):
#     22:55:42.46 2282 |     try:
#     22:55:42.46 2283 |         sig = obj.__signature__
#     22:55:42.46 !!! AttributeError: 'function' object has no attribute '__signature__'
#     22:55:42.46 !!! When getting attribute: obj.__signature__
#     22:55:42.46 2284 |     except AttributeError:
#     22:55:42.46 2285 |         pass
#     22:55:42.46 2294 |     try:
#     22:55:42.46 2295 |         partialmethod = obj._partialmethod
#     22:55:42.46 !!! AttributeError: 'function' object has no attribute '_partialmethod'
#     22:55:42.46 !!! When getting attribute: obj._partialmethod
#     22:55:42.46 2296 |     except AttributeError:
#     22:55:42.46 2297 |         pass
#     22:55:42.46 2322 |     if isfunction(obj) or _signature_is_functionlike(obj):
#     22:55:42.46 2325 |         return _signature_from_function(sigcls, obj,
#     22:55:42.46 2326 |                                         skip_bound_arg=skip_bound_arg)
#     22:55:42.46 2325 |         return _signature_from_function(sigcls, obj,
#     22:55:42.46 <<< Return value from _signature_from_callable: <Signature (cls, *args, **kwargs)>
# 22:55:42.46 2344 |             sig = _get_signature_of(call)
# 22:55:42.46 .................. sig = <Signature (cls, *args, **kwargs)>
# 22:55:42.46 2364 |         if sig is None:
# 22:55:42.46 2413 |     if sig is not None:
# 22:55:42.47 2416 |         if skip_bound_arg:
# 22:55:42.47 2417 |             return _signature_bound_method(sig)
# 22:55:42.47 <<< Return value from _signature_from_callable: <Signature (*args, **kwargs)>

# %%
fdb.dbprint(96, "Must check whether Foo's metaclass has its own __call__", "call = _signature_get_user_defined_method(type(obj), '__call__')",\
           "inspect.getdoc(_signature_get_user_defined_method)")
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ===============================================================     on line 96     ===============================================================
#      with example
# class BaseMeta(type):
#     # using __new__ from type
#     def __call__(cls, *args, **kwargs): pass
# class Foo_call(metaclass=BaseMeta):
#     def __init__(self, d, e, f): pass
#
# inspect._signature_from_callable(Foo_call, sigcls=inspect.Signature)
#
#
#         # First, let's see if it has an overloaded __call__ defined                                                                                     (94)
#         # in its metaclass                                                                                                                              (95)
#         call = _signature_get_user_defined_method(type(obj), '__call__')================================================================================(96)
#                                                                                                       Must check whether Foo's metaclass has its own __call__
#         if call is not None:                                                                                                                            (97)
#             sig = _get_signature_of(call)                                                                                                               (98)
#
# ==================================================================================================================Start of my srcline exploration:
#
#
#                                         call = _signature_get_user_defined_method(type(obj), '__call__') => call: <function BaseMeta.__call__ at 0x12743cb80>
#
#
# inspect.getdoc(_signature_get_user_defined_method) => inspect.getdoc(_signature_get_user_defined_method) : Private helper. Checks if ``cls`` has an attribute
# named ``method_name`` and returns it only if it is a
# pure python function.
# ====================================================================================================================End of my srcline exploration:
#
# <Signature (*args, **kwargs)>
#
# Review srcode with all comments added so far======================================================================================================
#                 # First argument of the wrapped callable is `*args`, as in================(66)
#                 # `partialmethod(lambda *args)`.==========================================(67)
#                 return sig================================================================(68)
#             else:=========================================================================(69)
#                 sig_params = tuple(sig.parameters.values())===============================(70)
#                 assert (not sig_params or=================================================(71)
#                         first_wrapped_param is not sig_params[0])=========================(72)
#                 new_params = (first_wrapped_param,) + sig_params==========================(73)
#                 return sig.replace(parameters=new_params)=================================(74)
#                                                                                                                                                         (75)
#     if isfunction(obj) or _signature_is_functionlike(obj):================================(76) # step 0: whatinside's sig is finally processed by _signature_from_function
#         # If it's a pure Python function, or an object that is duck type==================(77) # step 4: init func will be processed by _signature_from_function in the block above. see explorations below:
#         # of a Python function (Cython functions, for instance), then:====================(78)
#         return _signature_from_function(sigcls, obj,======================================(79)
#                                         skip_bound_arg=skip_bound_arg)====================(80)
#                                                                                                                                                         (81)
#     if _signature_is_builtin(obj):========================================================(82)
#         return _signature_from_builtin(sigcls, obj,=======================================(83)
#                                        skip_bound_arg=skip_bound_arg)=====================(84)
#                                                                                                                                                         (85)
#     if isinstance(obj, functools.partial):================================================(86)
#         wrapped_sig = _get_signature_of(obj.func)=========================================(87)
#         return _signature_get_partial(wrapped_sig, obj)===================================(88)
#                                                                                                                                                         (89)
#     sig = None============================================================================(90)
#     if isinstance(obj, type):=============================================================(91) # step 1: Foo is taken care of in this if block
#         # obj is a class or a metaclass===================================================(92)
#                                                                                                                                                         (93)
#         # First, let's see if it has an overloaded __call__ defined=======================(94)
#         # in its metaclass================================================================(95)
#         call = _signature_get_user_defined_method(type(obj), '__call__')==================(96) # step 8: Must check whether Foo's metaclass has its own __call__
#         if call is not None:==============================================================(97)
#             sig = _get_signature_of(call)=================================================(98)
#                                                                                                                                      part No.3 out of 6 parts
# <function inspect._signature_from_callable(obj, *, follow_wrapper_chains=True, skip_bound_arg=True, sigcls)>

# %%
fdb.dbprint(98, "_get_signature_of(call) will execute _signature_from_func(call) to get sig through step 4 on line 76")
# Out:
# =================================================     Investigating _signature_from_callable     =================================================
# ===============================================================     on line 98     ===============================================================
#      with example
# class BaseMeta(type):
#     # using __new__ from type
#     def __call__(cls, *args, **kwargs): pass
# class Foo_call(metaclass=BaseMeta):
#     def __init__(self, d, e, f): pass
#
# inspect._signature_from_callable(Foo_call, sigcls=inspect.Signature)
#
#
#         call = _signature_get_user_defined_method(type(obj), '__call__')                                                                                (96)
#         if call is not None:                                                                                                                            (97)
#             sig = _get_signature_of(call)===============================================================================================================(98)
#                                                          _get_signature_of(call) will execute _signature_from_func(call) to get sig through step 4 on line 76
#         else:                                                                                                                                           (99)
#             factory_method = None                                                                                                                       (100)
# <Signature (*args, **kwargs)>
#
# Review srcode with all comments added so far======================================================================================================
#                 # First argument of the wrapped callable is `*args`, as in================(66)
#                 # `partialmethod(lambda *args)`.==========================================(67)
#                 return sig================================================================(68)
#             else:=========================================================================(69)
#                 sig_params = tuple(sig.parameters.values())===============================(70)
#                 assert (not sig_params or=================================================(71)
#                         first_wrapped_param is not sig_params[0])=========================(72)
#                 new_params = (first_wrapped_param,) + sig_params==========================(73)
#                 return sig.replace(parameters=new_params)=================================(74)
#                                                                                                                                                         (75)
#     if isfunction(obj) or _signature_is_functionlike(obj):================================(76) # step 0: whatinside's sig is finally processed by _signature_from_function
#         # If it's a pure Python function, or an object that is duck type==================(77) # step 4: init func will be processed by _signature_from_function in the block above. see explorations below:
#         # of a Python function (Cython functions, for instance), then:====================(78)
#         return _signature_from_function(sigcls, obj,======================================(79)
#                                         skip_bound_arg=skip_bound_arg)====================(80)
#                                                                                                                                                         (81)
#     if _signature_is_builtin(obj):========================================================(82)
#         return _signature_from_builtin(sigcls, obj,=======================================(83)
#                                        skip_bound_arg=skip_bound_arg)=====================(84)
#                                                                                                                                                         (85)
#     if isinstance(obj, functools.partial):================================================(86)
#         wrapped_sig = _get_signature_of(obj.func)=========================================(87)
#         return _signature_get_partial(wrapped_sig, obj)===================================(88)
#                                                                                                                                                         (89)
#     sig = None============================================================================(90)
#     if isinstance(obj, type):=============================================================(91) # step 1: Foo is taken care of in this if block
#         # obj is a class or a metaclass===================================================(92)
#                                                                                                                                                         (93)
#         # First, let's see if it has an overloaded __call__ defined=======================(94)
#         # in its metaclass================================================================(95)
#         call = _signature_get_user_defined_method(type(obj), '__call__')==================(96) # step 8: Must check whether Foo's metaclass has its own __call__
#         if call is not None:==============================================================(97)
#             sig = _get_signature_of(call)=================================================(98) # step 9: _get_signature_of(call) will execute _signature_from_func(call) to get sig through step 4 on line 76
#                                                                                                                                      part No.3 out of 6 parts
# <function inspect._signature_from_callable(obj, *, follow_wrapper_chains=True, skip_bound_arg=True, sigcls)>

# %%
class BaseMeta(FixSigMeta): 
    # using __new__ of  FixSigMeta instead of type
    def __call__(cls, *args, **kwargs): pass

class Foo_call_fix(metaclass=BaseMeta): # Base
    def __init__(self, d, e, f): pass

inspect._signature_from_callable(Foo_call_fix, sigcls=inspect.Signature)
# Out:
# <Signature (d, e, f)>

# %%
example = """
class BaseMeta(FixSigMeta): 
    # using __new__ of  FixSigMeta instead of type
    def __call__(cls, *args, **kwargs): pass

class Foo_call_fix(metaclass=BaseMeta): # Base
    def __init__(self, d, e, f): pass

inspect._signature_from_callable(Foo_call_fix, sigcls=inspect.Signature)    
"""

# %%
fdb.takExample(example, Foo_call_fix=Foo_call_fix, inspect=inspect)

# %%
fdb.snoop()
# Out:
# 22:55:42.50 >>> Call to _signature_from_callable in File "/Users/Natsume/mambaforge/lib/python3.9/inspect.py", line 2246
# 22:55:42.50 ...... obj = <class '__main__.Foo_call_fix'>
# 22:55:42.50 ...... follow_wrapper_chains = True
# 22:55:42.50 ...... skip_bound_arg = True
# 22:55:42.50 ...... sigcls = <class 'inspect.Signature'>
# 22:55:42.50 2246 | def _signature_from_callable(obj, *,
# 22:55:42.50 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:42.50 2256 |                                 follow_wrapper_chains=follow_wrapper_chains,
# 22:55:42.50 2257 |                                 skip_bound_arg=skip_bound_arg,
# 22:55:42.50 2258 |                                 sigcls=sigcls)
# 22:55:42.50 2255 |     _get_signature_of = functools.partial(_signature_from_callable,
# 22:55:42.50 .......... _get_signature_of = functools.partial(<function _signature_from_call...und_arg=True, sigcls=<class 'inspect.Signature'>)
# 22:55:42.50 2260 |     if not callable(obj):
# 22:55:42.50 2263 |     if isinstance(obj, types.MethodType):
# 22:55:42.50 2274 |     if follow_wrapper_chains:
# 22:55:42.50 2275 |         obj = unwrap(obj, stop=(lambda f: hasattr(f, "__signature__")))
# 22:55:42.50 2276 |         if isinstance(obj, types.MethodType):
# 22:55:42.51 2282 |     try:
# 22:55:42.51 2283 |         sig = obj.__signature__
# 22:55:42.51 .............. sig = <Signature (d, e, f)>
# 22:55:42.51 2287 |         if sig is not None:
# 22:55:42.51 2288 |             if not isinstance(sig, Signature):
# 22:55:42.51 2292 |             return sig
# 22:55:42.51 <<< Return value from _signature_from_callable: <Signature (d, e, f)>

# %%
from fastcore.meta import _rm_self

# %%
fdbF = Fastdb(FixSigMeta, _rm_self=_rm_self)

# %%
fdbF.print()
# Out:
# ========================================================     Investigating FixSigMeta     ========================================================
# ==============================================================     on line None     ==============================================================
# ===========================================================     with example None     ============================================================
#
# class FixSigMeta(type):===================================================================(0)
#     "A metaclass that fixes the signature on classes that override `__new__`"=============(1)
#     def __new__(cls, name, bases, dict):==================================================(2)
#         res = super().__new__(cls, name, bases, dict)=====================================(3)
#         if res.__init__ is not object.__init__: res.__signature__ = _rm_self(inspect.signature(res.__init__))                                           (4)
#         return res========================================================================(5)
#                                                                                                                                                         (6)

# %%
example = """
# class BaseMeta(fdbF.outenv['FixSigMeta']): 
# class BaseMeta(fsm): 
class BaseMeta(fastcore.meta.FixSigMeta): 
# class BaseMeta(FixSigMeta): 
    # using __new__ of  FixSigMeta instead of type
    def __call__(cls, *args, **kwargs): pass

class Foo_call_fix(metaclass=BaseMeta): # Base
    def __init__(self, d, e, f): pass

pprint(inspect.signature(Foo_call_fix))
"""

# %%
import fastcore
from pprint import pprint

# %%
fdbF.takExample(example, inspect=inspect, fastcore=fastcore, pprint=pprint)

# %%
import fastcore

# %%
fsm = fdbF.dbprint(4, "what is res", "res", showdbsrc=False)
# Out:
# ========================================================     Investigating FixSigMeta     ========================================================
# ===============================================================     on line 4     ================================================================
#      with example
# # class BaseMeta(fdbF.outenv['FixSigMeta']):
# # class BaseMeta(fsm):
# class BaseMeta(fastcore.meta.FixSigMeta):
# # class BaseMeta(FixSigMeta):
#     # using __new__ of  FixSigMeta instead of type
#     def __call__(cls, *args, **kwargs): pass
#
# class Foo_call_fix(metaclass=BaseMeta): # Base
#     def __init__(self, d, e, f): pass
#
# pprint(inspect.signature(Foo_call_fix))
#
#
#     def __new__(cls, name, bases, dict):                                                                                                                (2)
#         res = super().__new__(cls, name, bases, dict)                                                                                                   (3)
#         if res.__init__ is not object.__init__: res.__signature__ = _rm_self(inspect.signature(res.__init__))===========================================(4)
#                                                                                                                                                   what is res
#         return res                                                                                                                                      (5)
#                                                                                                                                                         (6)
#
# ==================================================================================================================Start of my srcline exploration:
#
#
#                                                                                                                           res => res : <class 'Foo_call_fix'>
# ====================================================================================================================End of my srcline exploration:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 fsm = fdbF.dbprint(4, "what is res", "res", showdbsrc=False)
#
# File ~/Documents/fastdebug/fastdebug/core.py:473, in dbprint(self, idxsrc, cmt, expand, showdbsrc, *codes)
#     471 self.egEnv[self.orisrc.__name__] = locals()[self.orisrc.__name__]
#     472 if type(self.orisrc) == type:
# --> 473     exec(self.eg, {}, self.egEnv)
#     474 elif inspect.isfunction(self.orisrc):
#     475     example = self.takeoutExample()
#
# File <string>:12, in <module>
#
# NameError: name 'pprint' is not defined

# %%
import fastcore

# %%
class BaseMeta(fdbF.outenv['FixSigMeta']): 
# class BaseMeta(fsm): 
# class BaseMeta(fastcore.meta.FixSigMeta): 
# class BaseMeta(FixSigMeta): 
    # using __new__ of  FixSigMeta instead of type
    def __call__(cls, *args, **kwargs): pass

class Foo_call_fix(metaclass=BaseMeta): # Base
    def __init__(self, d, e, f): pass

inspect.signature(Foo_call_fix)

# %%
# class BaseMeta(fsm): 
# class BaseMeta(fastcore.meta.FixSigMeta): 
class BaseMeta(FixSigMeta): 
    # using __new__ of  FixSigMeta instead of type
    def __call__(cls, *args, **kwargs): pass

class Foo_call_fix(metaclass=BaseMeta): # Base
    def __init__(self, d, e, f): pass

inspect.signature(Foo_call_fix)

# %%
inspect.getsource(FixSigMeta)

# %%
inspect.getsource(fsm)

# %%
inspect.getsource(fastcore.meta.FixSigMeta)

# %%
inspect.getsource(fdbF.outenv['FixSigMeta'])
