# %% [raw]
# ---
# output-file: fastai_ptexports.html
# skip_exec: true
# title: 0018_fastai_pt2_2019_exports
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#export
TEST = 'test'

# %% [markdown]
# ## Export

# %%
# !python notebook2script.py 00_exports.ipynb

# %% [markdown]
# ### How it works:

# %%
import json
d = json.load(open('00_exports.ipynb','r'))['cells']

# %%
d[0]

# %%
from fastdebug.utils import *
# Out:
# <style>.container { width:100% !important; }</style>

# %%
ipy2md()
# Out:
# [jupytext] Reading /Users/Natsume/Documents/fastdebug/nbs/fastai_notebooks/0018_fastai_pt2_2019_exports.ipynb in format ipynb
# [jupytext] Writing /Users/Natsume/Documents/fastdebug/nbs/fastai_notebooks/0018_fastai_pt2_2019_exports.md
# cp to : /Users/Natsume/Documents/divefastai/Debuggable/jupytext
# move to : /Users/Natsume/Documents/fastdebug/mds/fastai_notebooks/
# [NbConvertApp] Converting notebook /Users/Natsume/Documents/fastdebug/nbs/fastai_notebooks/0018_fastai_pt2_2019_exports.ipynb to markdown
# [NbConvertApp] Writing 215 bytes to /Users/Natsume/Documents/fastdebug/nbs/fastai_notebooks/0018_fastai_pt2_2019_exports.md
# copy to : /Users/Natsume/Documents/fastdebug/mds_output
# move to : /Users/Natsume/Documents/divefastai/Debuggable/nbconvert
