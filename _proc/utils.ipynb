# %% [raw]
# ---
# description: little functions to tell you the basics of a module
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Expand cells

# %%
#|output: asis
#| echo: false
show_doc(expandcell)
# Out:
# ---
#
# [source](https://github.com/EmbraceLife/fastdebug/blob/master/fastdebug/utils.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### expandcell
#
# >      expandcell ()

# %% [markdown]
# ## Import fastcore env

# %% [markdown]
# ## to inspect a class

# %%
#|output: asis
#| echo: false
show_doc(inspect_class)
# Out:
# ---
#
# [source](https://github.com/EmbraceLife/fastdebug/blob/master/fastdebug/utils.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### inspect_class
#
# >      inspect_class (c)

# %% [markdown]
# ## is it a metaclass?

# %%
#|output: asis
#| echo: false
show_doc(ismetaclass)
# Out:
# ---
#
# [source](https://github.com/EmbraceLife/fastdebug/blob/master/fastdebug/utils.py#L78){target="_blank" style="float:right; font-size:smaller"}
#
# ### ismetaclass
#
# >      ismetaclass (mc)

# %%
from fastcore.meta import *

# %%
ismetaclass(FixSigMeta)
# Out:
# True

# %%
ismetaclass(PrePostInitMeta)
# Out:
# True

# %% [markdown]
# ## whatinside a module of a library

# %%
#|output: asis
#| echo: false
show_doc(whatinside)
# Out:
# ---
#
# [source](https://github.com/EmbraceLife/fastdebug/blob/master/fastdebug/utils.py#L89){target="_blank" style="float:right; font-size:smaller"}
#
# ### whatinside
#
# >      whatinside (mo, dun:bool=False, func:bool=False, clas:bool=False,
# >                  bltin:bool=False, lib:bool=False, cal:bool=False)
#
# Check what inside a module: `__all__`, functions, classes, builtins, and callables
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | mo |  |  | module, e.g., `import fastcore.all as fa`, use `fa` here |
# | dun | bool | False | print all items in __all__ |
# | func | bool | False | print all user defined functions |
# | clas | bool | False | print all class objects |
# | bltin | bool | False | print all builtin funcs or methods |
# | lib | bool | False | print all the modules of the library it belongs to |
# | cal | bool | False | print all callables |

# %%
whatinside(inspect)
# Out:
# inspect has:
# 0 items in its __all__, and
# 86 user defined functions,
# 23 classes or class objects,
# 0 builtin funcs and methods, and
# 109 callables.

# %%
whatinside(inspect, func=True)
# Out:
# inspect has:
# 0 items in its __all__, and
# 86 user defined functions,
# 23 classes or class objects,
# 0 builtin funcs and methods, and
# 109 callables.
#
# The user defined functions are:
# ['_check_class',
#  '_check_instance',
#  '_findclass',
#  '_finddoc',
#  '_has_code_flag',
#  '_is_type',
#  '_main',
#  '_missing_arguments',
#  '_shadowed_dict',
#  '_signature_bound_method',
#  '_signature_from_builtin',
#  '_signature_from_callable',
#  '_signature_from_function',
#  '_signature_fromstr',
#  '_signature_get_bound_param',
#  '_signature_get_partial',
#  '_signature_get_user_defined_method',
#  '_signature_is_builtin',
#  '_signature_is_functionlike',
#  '_signature_strip_non_python_syntax',
#  '_static_getmro',
#  '_too_many',
#  'classify_class_attrs',
#  'cleandoc',
#  'currentframe',
#  'findsource',
#  'formatannotation',
#  'formatannotationrelativeto',
#  'formatargspec',
#  'formatargvalues',
#  'getabsfile',
#  'getargs',
#  'getargspec',
#  'getargvalues',
#  'getattr_static',
#  'getblock',
#  'getcallargs',
#  'getclasstree',
#  'getclosurevars',
#  'getcomments',
#  'getcoroutinelocals',
#  'getcoroutinestate',
#  'getdoc',
#  'getfile',
#  'getframeinfo',
#  'getfullargspec',
#  'getgeneratorlocals',
#  'getgeneratorstate',
#  'getinnerframes',
#  'getlineno',
#  'getmembers',
#  'getmodule',
#  'getmodulename',
#  'getmro',
#  'getouterframes',
#  'getsource',
#  'getsourcefile',
#  'getsourcelines',
#  'indentsize',
#  'isabstract',
#  'isasyncgen',
#  'isasyncgenfunction',
#  'isawaitable',
#  'isbuiltin',
#  'isclass',
#  'iscode',
#  'iscoroutine',
#  'iscoroutinefunction',
#  'isdatadescriptor',
#  'isframe',
#  'isfunction',
#  'isgenerator',
#  'isgeneratorfunction',
#  'isgetsetdescriptor',
#  'ismemberdescriptor',
#  'ismethod',
#  'ismethoddescriptor',
#  'ismodule',
#  'isroutine',
#  'istraceback',
#  'namedtuple',
#  'signature',
#  'stack',
#  'trace',
#  'unwrap',
#  'walktree']

# %%
whatinside(inspect, clas=True)
# Out:
# inspect has:
# 0 items in its __all__, and
# 86 user defined functions,
# 23 classes or class objects,
# 0 builtin funcs and methods, and
# 109 callables.
#
# The class objects are:
# ['ArgInfo',
#  'ArgSpec',
#  'Arguments',
#  'Attribute',
#  'BlockFinder',
#  'BoundArguments',
#  'ClassFoundException',
#  'ClosureVars',
#  'EndOfBlock',
#  'FrameInfo',
#  'FullArgSpec',
#  'OrderedDict',
#  'Parameter',
#  'Signature',
#  'Traceback',
#  '_ClassFinder',
#  '_ClassMethodWrapper',
#  '_MethodWrapper',
#  '_ParameterKind',
#  '_WrapperDescriptor',
#  '_empty',
#  '_void',
#  'attrgetter']

# %% [markdown]
# ## whichversion of a library

# %%
#|output: asis
#| echo: false
show_doc(whichversion)
# Out:
# ---
#
# [source](https://github.com/EmbraceLife/fastdebug/blob/master/fastdebug/utils.py#L129){target="_blank" style="float:right; font-size:smaller"}
#
# ### whichversion
#
# >      whichversion (libname:str, req:bool=False, file:bool=False)
#
# Give you library version and other basic info.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | libname | str |  | library name not string |
# | req | bool | False | print lib requirements |
# | file | bool | False | print all lib files |

# %%
whichversion("python")
# Out:
# python: 3.9.13

# %%
whichversion("fastcore")
# Out:
# fastcore: 1.5.22
# Python supercharged for fastai development
# Jeremy Howard and Sylvain Gugger
# https://github.com/fastai/fastcore/
# python_version: >=3.7
# /Users/Natsume/mambaforge/lib/python3.9/site-packages/fastcore

# %%
whichversion("fastai")
# Out:
# fastai: 2.7.9
# fastai simplifies training fast and accurate neural nets using modern best practices
# Jeremy Howard, Sylvain Gugger, and contributors
# https://github.com/fastai/fastai/tree/master/
# python_version: >=3.7
# /Users/Natsume/mambaforge/lib/python3.9/site-packages/fastai

# %%
whichversion("jupyter")
# Out:
# jupyter: 1.0.0
# Jupyter metapackage. Install all the Jupyter components in one go.
# Jupyter Development Team
# http://jupyter.org
# python_version: None
# /Users/Natsume/mambaforge/lib/python3.9/site-packages/jupyter

# %%
try:
    whichversion("inspect")
except: 
    print("inspect won't work here")
# Out:
# inspect won't work here

# %%
#|output: asis
#| echo: false
show_doc(tstenv)
# Out:
# ---
#
# [source](https://github.com/EmbraceLife/fastdebug/blob/master/fastdebug/utils.py#L150){target="_blank" style="float:right; font-size:smaller"}
#
# ### tstenv
#
# >      tstenv (outenv={'__name__': '__main__', '__doc__': 'Automatically created
# >              module for IPython interactive environment', '__package__': None,
# >              '__loader__': None, '__spec__': None, '__builtin__': <module
# >              'builtins' (built-in)>, '__builtins__': <module 'builtins'
# >              (built-in)>, '_ih': <function noop at 0x1036630d0>, '_oh':
# >              <function noop at 0x1036630d0>, '_dh': <function noop at
# >              0x1036630d0>, 'In': <function noop at 0x1036630d0>, 'Out':
# >              <function noop at 0x1036630d0>, 'get_ipython': <bound method
# >              InteractiveShell.get_ipython of <execnb.shell.CaptureShell object
# >              at 0x103691820>>, 'exit': <IPython.core.autocall.ZMQExitAutocall
# >              object at 0x10376c3d0>, 'quit':
# >              <IPython.core.autocall.ZMQExitAutocall object at 0x10376c3d0>,
# >              '_': '', '__': '', '___': '', 'show_doc': <function show_doc at
# >              0x1035d33a0>, 'expandcell': <function expandcell at 0x103807040>,
# >              'expand': None, 'TEST_IMAGE': 'images/puppy.jpg',
# >              'TEST_IMAGE_BW': 'images/mnist3.png', 'exception':
# >              <fastcore.test.ExceptionExpected object at 0x10202f940>,
# >              'test_fail': <function test_fail at 0x102028820>, 'test':
# >              <function test at 0x1020289d0>, 'nequals': <function nequals at
# >              0x102028a60>, 'test_eq': <function test_eq at 0x102028af0>,
# >              'test_eq_type': <function test_eq_type at 0x102028b80>,
# >              'test_ne': <function test_ne at 0x102028c10>, 'is_close':
# >              <function is_close at 0x102028ca0>, 'test_close': <function
# >              test_close at 0x102028d30>, 'test_is': <function test_is at
# >              0x102028dc0>, 'test_shuffled': <function test_shuffled at
# >              0x102028e50>, 'test_stdout': <function test_stdout at
# >              0x102028ee0>, 'test_warns': <function test_warns at 0x102028f70>,
# >              'test_fig_exists': <function test_fig_exists at 0x102032040>,
# >              'ExceptionExpected': <class 'fastcore.test.ExceptionExpected'>,
# >              'inspect_class': <function inspect_class at 0x1038070d0>,
# >              'ismetaclass': <function ismetaclass at 0x1039a61f0>, 'test_sig':
# >              <function test_sig at 0x102028550>, 'FixSigMeta': <class
# >              'fastcore.meta.FixSigMeta'>, 'PrePostInitMeta': <class
# >              'fastcore.meta.PrePostInitMeta'>, 'AutoInit': <class
# >              'fastcore.meta.AutoInit'>, 'NewChkMeta': <class
# >              'fastcore.meta.NewChkMeta'>, 'BypassNewMeta': <class
# >              'fastcore.meta.BypassNewMeta'>, 'empty2none': <function
# >              empty2none at 0x102032310>, 'anno_dict': <function anno_dict at
# >              0x102032670>, 'use_kwargs_dict': <function use_kwargs_dict at
# >              0x102032790>, 'use_kwargs': <function use_kwargs at 0x102032820>,
# >              'delegates': <function delegates at 0x1020328b0>, 'method':
# >              <function method at 0x102032940>, 'funcs_kwargs': <function
# >              funcs_kwargs at 0x102032a60>, 'os': <module 'os' from
# >              '/Users/Natsume/mambaforge/lib/python3.9/os.py'>, 'pkgutil':
# >              <module 'pkgutil' from
# >              '/Users/Natsume/mambaforge/lib/python3.9/pkgutil.py'>, 'pprint':
# >              <function pprint at 0x1018011f0>, 'inspect': <module 'inspect'
# >              from '/Users/Natsume/mambaforge/lib/python3.9/inspect.py'>,
# >              'whatinside': <function whatinside at 0x103aa7790>, 'version':
# >              <function version at 0x103add5e0>, 'metadata': <function metadata
# >              at 0x103add550>, 'distribution': <function distribution at
# >              0x1037bf430>, 'python_version': <function python_version at
# >              0x1014c6ca0>, 'whichversion': <function whichversion at
# >              0x1037bf1f0>, 'tstenv': <function tstenv at 0x1037bf160>})

# %%
tstenv()
# Out:
# out global env has 47 vars
# inner global env has 47 vars
# inner local env has 47 vars
# ['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh']
# ['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh']
# out env['__name__']: __main__
# inner env['__name__']: __main__

# %%
len(globals().keys())
# Out:
# 48
