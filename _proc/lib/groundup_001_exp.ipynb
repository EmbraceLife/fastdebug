# %% [raw]
# ---
# output-file: groundup_exp.html
# title: 0000_groundup_exp
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## nb_name

# %%
from fastdebug.utils import *
# Out:
# <style>.container { width:100% !important; }</style>

# %%
nbname = nb_name()

# %%
nbname
# Out:
# ''

# %% [markdown]
# ## notebook as json

# %%
import json

# %%
if bool(nbname):
    d = json.load(open(nbname,'r'))
else: 
    d = None

# %%
d

# %%
all_src = []
if bool(d):
    for dct in d['cells']:
        all_src = all_src + dct['source']
all_src
# Out:
# []
